# %% [markdown]
# <a href="https://colab.research.google.com/github/pradh/mixer/blob/countufix2/internal/store/files/Safely_adding_names_without_county_to_NL_Place_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Install

# !pip install datacommons

import datacommons as dc
import requests
# Out:
# Collecting datacommons
#   Downloading datacommons-1.4.3-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 700.8 kB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from datacommons) (1.16.0)
# Installing collected packages: datacommons
# Successfully installed datacommons-1.4.3

# %%
# @title Get all counties

counties = dc.get_places_in(['country/USA'], 'County')['country/USA']
county2names = dc.get_property_values(counties, 'name')
county2names = {k: v[0] for k, v in county2names.items()}
len(county2names)
# Out:
# 3238

# %%
# @title Get all states

# 'geoId/xx' => 8
state_dcids = list(set([c[:8] for c in counties]))
state_dcids.sort()
state2names = dc.get_property_values(state_dcids, 'name')
state2names = {k: v[0] for k, v in state2names.items()}
len(state2names)
# Out:
# 53

# %%
# @title Prepare `recognize/places` queries
county2queries = {}

for cid, cname in county2names.items():
  sid = cid[:8]
  sname = state2names[sid]

  if not cname.lower().endswith(' county'):
    continue
  cname_short = cname.replace(' County', '').replace(' county', '')

  county2queries[cid] = [
    f'{cname_short} {sname}',
    f'{cname_short} US',
  ]

queries = list(set([n[0] for n in county2queries.values()] + [n[1] for n in county2queries.values()]))
print(county2queries['geoId/20145'])
len(county2queries)
# Out:
# ['Pawnee Kansas', 'Pawnee US']
# 3003

# %%
# @title Make the `recognize/places` call
def recognize(queries):
  resp = requests.post('https://api.datacommons.org/v1/recognize/places',
                       headers={'X-API-Key': 'AIzaSyCTI4Xz-UW_G2Q2RfknhcfdAnTHq5X5XuI'},
                      json={'queries': queries}).json()
  ans = {}
  for q, v in resp['queryItems'].items():
    item = v.get('items', [{}])[0]
    name = item.get('span')
    dcid = item.get('places', [{}])[0].get('dcid', '')
    if q == name:
      ans[q] = dcid
    else:
      ans[q] = ''
  return ans

ans = recognize(queries)

# %%
# @title Classify safe / maybe-unsafe counties

safe_counties = []
maybe_unsafe_counties = {}
for cid, (in_st, in_us) in county2queries.items():
  s_id = ans[in_st]
  us_id = ans[in_us]
  if not s_id:
    if us_id:
      maybe_unsafe_counties[cid] = set([us_id])
    else:
      safe_counties.append(cid)
  else:
    if us_id:
      maybe_unsafe_counties[cid] = set([s_id, us_id])
    else:
      maybe_unsafe_counties[cid] = set([s_id])

len(safe_counties), len(maybe_unsafe_counties)
# Out:
# (578, 2425)

# %%
# @title Get population of maybe-unsafe counties and suppressed places

places_for_pop = set()
places_for_pop.update([p for p in maybe_unsafe_counties.keys()])
places_for_pop.update([p for places in maybe_unsafe_counties.values() for p in places])
places_for_pop  =list(places_for_pop)
print(places_for_pop[0])

place2stat = dc.get_stats(places_for_pop, 'Count_Person')
place2stat = {k: list(v.get('data', {}).values())[0] for k, v in place2stat.items()}
print(len(place2stat))
# Out:
# geoId/2167458
# 4157

# %%
# @title Classify the maybe-unsafe counties as def-unsafe (if suppressing sizeable places), or safe

def_unsafe_counties = {}
for k, vals in maybe_unsafe_counties.items():
  kpop = place2stat[k]

  for v in vals:
    vpop = place2stat[v]
    if kpop > vpop and vpop > 10000:
      # `v` is sizeable place that `k` is suppressing!
      def_unsafe_counties.setdefault(k, set()).add(v)

  if k not in def_unsafe_counties:
    safe_counties.append(k)


len(safe_counties), len(def_unsafe_counties)
# Out:
# (2437, 566)

# %%
# @title Final list of unsafe counties

for k, vals in def_unsafe_counties.items():
  print(f'{k} ({county2names[k]}) will suppress {", ".join(vals)}')
# Out:
# geoId/01003 (Baldwin County) will suppress geoId/3604143
# geoId/01013 (Butler County) will suppress geoId/4210464
# geoId/01015 (Calhoun County) will suppress geoId/1312456
# geoId/01023 (Choctaw County) will suppress geoId/4014200
# geoId/01027 (Clay County) will suppress geoId/0115256
# geoId/01043 (Cullman County) will suppress geoId/0118976
# geoId/01049 (DeKalb County) will suppress geoId/1719161
# geoId/01061 (Geneva County) will suppress geoId/1728872
# geoId/01073 (Jefferson County) will suppress geoId/1341988
# geoId/01089 (Madison County) will suppress geoId/0145784, geoId/5548000
# geoId/01095 (Marshall County) will suppress geoId/4846776
# geoId/01097 (Mobile County) will suppress geoId/0150000
# geoId/01101 (Montgomery County) will suppress geoId/0151000
# geoId/01117 (Shelby County) will suppress geoId/3761200
# geoId/01121 (Talladega County) will suppress geoId/0174592
# geoId/01125 (Tuscaloosa County) will suppress geoId/0177256
# geoId/01127 (Walker County) will suppress geoId/2682960
# geoId/04009 (Graham County) will suppress geoId/5327785
# geoId/04013 (Maricopa County) will suppress geoId/0444410
# geoId/04027 (Yuma County) will suppress geoId/0485540
# geoId/05007 (Benton County) will suppress geoId/0505290
# geoId/05009 (Boone County) will suppress geoId/3707080
# geoId/05015 (Carroll County) will suppress geoId/1911080
# geoId/05019 (Clark County) will suppress geoId/3413150
# geoId/05069 (Jefferson County) will suppress geoId/1341988
# geoId/05089 (Marion County) will suppress geoId/0544180
# geoId/05131 (Sebastian County) will suppress geoId/1264825
# geoId/06001 (Alameda County) will suppress geoId/0600562
# geoId/06007 (Butte County) will suppress geoId/3011397
# geoId/06017 (El Dorado County) will suppress geoId/0521070
# geoId/06019 (Fresno County) will suppress geoId/0627000
# geoId/06025 (Imperial County) will suppress geoId/0636280
# geoId/06037 (Los Angeles County) will suppress geoId/0644000
# geoId/06039 (Madera County) will suppress geoId/0645022
# geoId/06047 (Merced County) will suppress geoId/0646898
# geoId/06053 (Monterey County) will suppress geoId/0648872
# geoId/06055 (Napa County) will suppress geoId/0650258
# geoId/06059 (Orange County) will suppress geoId/0653980
# geoId/06065 (Riverside County) will suppress geoId/0662000
# geoId/06067 (Sacramento County) will suppress geoId/0664000
# geoId/06069 (San Benito County) will suppress geoId/4865036
# geoId/06071 (San Bernardino County) will suppress geoId/0665000
# geoId/06073 (San Diego County) will suppress geoId/0666000
# geoId/06079 (San Luis Obispo County) will suppress geoId/0668154
# geoId/06081 (San Mateo County) will suppress geoId/0668252
# geoId/06083 (Santa Barbara County) will suppress geoId/0669070
# geoId/06085 (Santa Clara County) will suppress geoId/0669084
# geoId/06087 (Santa Cruz County) will suppress geoId/0669112
# geoId/06097 (Sonoma County) will suppress geoId/0672646
# geoId/06107 (Tulare County) will suppress geoId/0680644
# geoId/06111 (Ventura County) will suppress geoId/0682282
# geoId/08013 (Boulder County) will suppress geoId/0807850
# geoId/08035 (Douglas County) will suppress geoId/0420050
# geoId/08037 (Eagle County) will suppress geoId/1623410
# geoId/08041 (El Paso County) will suppress geoId/4824000
# geoId/08045 (Garfield County) will suppress geoId/3425770
# geoId/08059 (Jefferson County) will suppress geoId/1341988
# geoId/08067 (La Plata County) will suppress geoId/2445750
# geoId/08085 (Montrose County) will suppress geoId/0851745
# geoId/08101 (Pueblo County) will suppress geoId/0862000
# geoId/08117 (Summit County) will suppress geoId/3471430
# geoId/09001 (Fairfield County) will suppress geoId/0926620, geoId/0623182
# geoId/09003 (Hartford County) will suppress geoId/0937000
# geoId/09007 (Middlesex County) will suppress geoId/3445900
# geoId/09009 (New Haven County) will suppress geoId/0952000
# geoId/09011 (New London County) will suppress geoId/0952280
# geoId/09013 (Tolland County) will suppress geoId/0976290
# geoId/09015 (Windham County) will suppress geoId/0986790
# geoId/10001 (Kent County) will suppress geoId/5335415
# geoId/10003 (New Castle County) will suppress geoId/4253368
# geoId/10005 (Sussex County) will suppress geoId/5578750
# geoId/12001 (Alachua County) will suppress geoId/1200375
# geoId/12003 (Baker County) will suppress geoId/2203985
# geoId/12017 (Citrus County) will suppress geoId/0613560
# geoId/12019 (Clay County) will suppress geoId/3616067
# geoId/12039 (Gadsden County) will suppress geoId/0128696
# geoId/12053 (Hernando County) will suppress geoId/2831780
# geoId/12055 (Highlands County) will suppress geoId/3634550
# geoId/12057 (Hillsborough County) will suppress geoId/0633798
# geoId/12083 (Marion County) will suppress geoId/1949485
# geoId/12085 (Martin County) will suppress geoId/4746240
# geoId/12087 (Monroe County) will suppress geoId/2251410
# geoId/12095 (Orange County) will suppress geoId/0653980
# geoId/12101 (Pasco County) will suppress geoId/5353545
# geoId/12113 (Santa Rosa County) will suppress geoId/0670098
# geoId/12115 (Sarasota County) will suppress geoId/1264175
# geoId/12117 (Seminole County) will suppress geoId/1264975
# geoId/12119 (Sumter County) will suppress geoId/4570405
# geoId/13009 (Baldwin County) will suppress geoId/3604143
# geoId/13015 (Bartow County) will suppress geoId/1203675
# geoId/13045 (Carroll County) will suppress geoId/1911080
# geoId/13051 (Chatham County) will suppress geoId/1712684
# geoId/13063 (Clayton County) will suppress geoId/3712860
# geoId/13073 (Columbia County) will suppress geoId/4516000
# geoId/13077 (Coweta County) will suppress geoId/4017800
# geoId/13087 (Decatur County) will suppress geoId/1322052
# geoId/13089 (DeKalb County) will suppress geoId/1719161
# geoId/13097 (Douglas County) will suppress geoId/1323872, geoId/0420050
# geoId/13103 (Effingham County) will suppress geoId/1722736
# geoId/13121 (Fulton County) will suppress geoId/2926182
# geoId/13163 (Jefferson County) will suppress geoId/1341988
# geoId/13179 (Liberty County) will suppress geoId/2942032
# geoId/13205 (Mitchell County) will suppress geoId/4643100
# geoId/13207 (Monroe County) will suppress geoId/1352192
# geoId/13217 (Newton County) will suppress geoId/2545560
# geoId/13295 (Walker County) will suppress geoId/2682960
# geoId/13321 (Worth County) will suppress geoId/1783518
# geoId/15003 (Honolulu County) will suppress geoId/1517000
# geoId/16001 (Ada County) will suppress geoId/4000200
# geoId/16027 (Canyon County) will suppress geoId/4812532
# geoId/16051 (Jefferson County) will suppress geoId/1341988
# geoId/16053 (Jerome County) will suppress geoId/1641320
# geoId/16083 (Twin Falls County) will suppress geoId/1682810
# geoId/16085 (Valley County) will suppress geoId/0178204
# geoId/17007 (Boone County) will suppress geoId/3707080
# geoId/17015 (Carroll County) will suppress geoId/1911080
# geoId/17019 (Champaign County) will suppress geoId/1712385
# geoId/17037 (DeKalb County) will suppress geoId/1719161
# geoId/17041 (Douglas County) will suppress geoId/0420050
# geoId/17049 (Effingham County) will suppress geoId/1722736
# geoId/17057 (Fulton County) will suppress geoId/2926182
# geoId/17081 (Jefferson County) will suppress geoId/1341988
# geoId/17091 (Kankakee County) will suppress geoId/1738934
# geoId/17093 (Kendall County) will suppress geoId/1236100
# geoId/17105 (Livingston County) will suppress geoId/3440890
# geoId/17111 (McHenry County) will suppress geoId/1745694
# geoId/17113 (McLean County) will suppress geoId/5148376
# geoId/17115 (Macon County) will suppress geoId/1349000
# geoId/17121 (Marion County) will suppress geoId/1746916
# geoId/17135 (Montgomery County) will suppress geoId/1750218
# geoId/17143 (Peoria County) will suppress geoId/1759000
# geoId/17161 (Rock Island County) will suppress geoId/1765078
# geoId/17183 (Vermilion County) will suppress geoId/3979716
# geoId/17185 (Wabash County) will suppress geoId/1879370
# geoId/18003 (Allen County) will suppress geoId/4801924
# geoId/18011 (Boone County) will suppress geoId/3707080
# geoId/18015 (Carroll County) will suppress geoId/1911080
# geoId/18019 (Clark County) will suppress geoId/3413150
# geoId/18033 (DeKalb County) will suppress geoId/1719161
# geoId/18039 (Elkhart County) will suppress geoId/1820728
# geoId/18049 (Fulton County) will suppress geoId/2926182
# geoId/18057 (Hamilton County) will suppress geoId/3933012
# geoId/18061 (Harrison County) will suppress geoId/3632402
# geoId/18067 (Howard County) will suppress geoId/5535950
# geoId/18069 (Huntington County) will suppress geoId/1835302
# geoId/18073 (Jasper County) will suppress geoId/1837782
# geoId/18077 (Jefferson County) will suppress geoId/1341988
# geoId/18079 (Jennings County) will suppress geoId/2937178
# geoId/18087 (LaGrange County) will suppress geoId/1344340
# geoId/18095 (Madison County) will suppress geoId/1845990
# geoId/18097 (Marion County) will suppress geoId/1846908, geoId/1949485
# geoId/18099 (Marshall County) will suppress geoId/4846776
# geoId/18105 (Monroe County) will suppress geoId/2251410
# geoId/18141 (St. Joseph County) will suppress geoId/2964550
# geoId/18145 (Shelby County) will suppress geoId/3761200
# geoId/18147 (Spencer County) will suppress geoId/2566105
# geoId/18153 (Sullivan County) will suppress geoId/3671993
# geoId/18165 (Vermillion County) will suppress geoId/4666700
# geoId/18169 (Wabash County) will suppress geoId/1879370
# geoId/18175 (Washington County) will suppress geoId/1880504
# geoId/18177 (Wayne County) will suppress geoId/3477840
# geoId/19015 (Boone County) will suppress geoId/1907480, geoId/3707080
# geoId/19023 (Butler County) will suppress geoId/4210464
# geoId/19027 (Carroll County) will suppress geoId/1911080
# geoId/19045 (Clinton County) will suppress geoId/1914430, geoId/2417900
# geoId/19061 (Dubuque County) will suppress geoId/1922395
# geoId/19099 (Jasper County) will suppress geoId/1837782
# geoId/19101 (Jefferson County) will suppress geoId/1341988
# geoId/19127 (Marshall County) will suppress geoId/4846776
# geoId/19139 (Muscatine County) will suppress geoId/1955110
# geoId/19187 (Webster County) will suppress geoId/2573895
# geoId/19193 (Woodbury County) will suppress geoId/2771428
# geoId/20005 (Atchison County) will suppress geoId/2002900
# geoId/20015 (Butler County) will suppress geoId/4210464
# geoId/20045 (Douglas County) will suppress geoId/0420050
# geoId/20079 (Harvey County) will suppress geoId/2233245
# geoId/20087 (Jefferson County) will suppress geoId/1341988
# geoId/20103 (Leavenworth County) will suppress geoId/2039000
# geoId/20113 (McPherson County) will suppress geoId/2043950
# geoId/20133 (Neosho County) will suppress geoId/2951572
# geoId/20177 (Shawnee County) will suppress geoId/2064500
# geoId/20191 (Sumner County) will suppress geoId/5368435
# geoId/20209 (Wyandotte County) will suppress geoId/2688900
# geoId/21011 (Bath County) will suppress geoId/3604770
# geoId/21015 (Boone County) will suppress geoId/3707080
# geoId/21037 (Campbell County) will suppress geoId/0610345
# geoId/21041 (Carroll County) will suppress geoId/1911080
# geoId/21049 (Clark County) will suppress geoId/3413150
# geoId/21073 (Franklin County) will suppress geoId/2128918
# geoId/21101 (Henderson County) will suppress geoId/2135866
# geoId/21107 (Hopkins County) will suppress geoId/2730140
# geoId/21111 (Jefferson County) will suppress geoId/1341988
# geoId/21125 (Laurel County) will suppress geoId/2445900
# geoId/21157 (Marshall County) will suppress geoId/4846776
# geoId/21159 (Martin County) will suppress geoId/4746240
# geoId/21193 (Perry County) will suppress geoId/1360340
# geoId/21211 (Shelby County) will suppress geoId/3761200
# geoId/21215 (Spencer County) will suppress geoId/2566105
# geoId/21227 (Warren County) will suppress geoId/2684000
# geoId/23005 (Cumberland County) will suppress geoId/4420080
# geoId/23017 (Oxford County) will suppress geoId/2854840
# geoId/23025 (Somerset County) will suppress geoId/3468370
# geoId/23031 (York County) will suppress geoId/2387985, geoId/4287048
# geoId/24005 (Baltimore County) will suppress geoId/2404000
# geoId/24013 (Carroll County) will suppress geoId/1911080
# geoId/24021 (Frederick County) will suppress geoId/2430325
# geoId/24027 (Howard County) will suppress geoId/5535950
# geoId/24031 (Montgomery County) will suppress geoId/0151000
# geoId/24039 (Somerset County) will suppress geoId/3468370
# geoId/25001 (Barnstable County) will suppress geoId/2503690
# geoId/25005 (Bristol County) will suppress geoId/0908420
# geoId/25009 (Essex County) will suppress geoId/2426600
# geoId/25011 (Franklin County) will suppress geoId/2525100
# geoId/25017 (Middlesex County) will suppress geoId/3445900
# geoId/25019 (Nantucket County) will suppress geoId/2543755
# geoId/25021 (Norfolk County) will suppress geoId/5157000, geoId/2546050
# geoId/25023 (Plymouth County) will suppress geoId/2554310, geoId/2751730
# geoId/25025 (Suffolk County) will suppress geoId/5176432
# geoId/25027 (Worcester County) will suppress geoId/2582000
# geoId/26007 (Alpena County) will suppress geoId/2601740
# geoId/26025 (Calhoun County) will suppress geoId/1312456
# geoId/26037 (Clinton County) will suppress geoId/2417900
# geoId/26043 (Dickinson County) will suppress geoId/3819620
# geoId/26059 (Hillsdale County) will suppress geoId/3431920
# geoId/26063 (Huron County) will suppress geoId/4631060
# geoId/26067 (Ionia County) will suppress geoId/2640860
# geoId/26075 (Jackson County) will suppress geoId/2641420, geoId/2836000
# geoId/26077 (Kalamazoo County) will suppress geoId/2642160
# geoId/26081 (Kent County) will suppress geoId/5335415
# geoId/26093 (Livingston County) will suppress geoId/3440890
# geoId/26099 (Macomb County) will suppress geoId/1745889
# geoId/26103 (Marquette County) will suppress geoId/2651900
# geoId/26111 (Midland County) will suppress geoId/2653780
# geoId/26115 (Monroe County) will suppress geoId/2655020, geoId/2251410
# geoId/26121 (Muskegon County) will suppress geoId/2656320
# geoId/26125 (Oakland County) will suppress geoId/0653000
# geoId/26137 (Otsego County) will suppress geoId/2749138
# geoId/26139 (Ottawa County) will suppress geoId/1756926
# geoId/26145 (Saginaw County) will suppress geoId/2670520
# geoId/26159 (Van Buren County) will suppress geoId/0571480
# geoId/26163 (Wayne County) will suppress geoId/3477840, geoId/2684940
# geoId/27003 (Anoka County) will suppress geoId/2701720
# geoId/27009 (Benton County) will suppress geoId/0505290
# geoId/27019 (Carver County) will suppress wikidataId/Q372315
# geoId/27027 (Clay County) will suppress geoId/3616067
# geoId/27041 (Douglas County) will suppress geoId/0420050
# geoId/27045 (Fillmore County) will suppress geoId/0624092
# geoId/27091 (Martin County) will suppress geoId/4746240
# geoId/27123 (Ramsey County) will suppress geoId/2753026
# geoId/27169 (Winona County) will suppress geoId/2771032
# geoId/27171 (Wright County) will suppress geoId/1278800
# geoId/28011 (Bolivar County) will suppress geoId/2906976
# geoId/28033 (DeSoto County) will suppress geoId/4820092
# geoId/28043 (Grenada County) will suppress geoId/2829460
# geoId/28047 (Harrison County) will suppress geoId/3632402
# geoId/28089 (Madison County) will suppress geoId/2844520
# geoId/28093 (Marshall County) will suppress geoId/4846776
# geoId/28109 (Pearl River County) will suppress geoId/3656902
# geoId/29019 (Boone County) will suppress geoId/3707080
# geoId/29023 (Butler County) will suppress geoId/4210464
# geoId/29027 (Callaway County) will suppress geoId/1209725
# geoId/29031 (Cape Girardeau County) will suppress geoId/2911242
# geoId/29047 (Clay County) will suppress geoId/3616067
# geoId/29065 (Dent County) will suppress geoId/3921742
# geoId/29071 (Franklin County) will suppress geoId/4727740
# geoId/29091 (Howell County) will suppress geoId/2639540
# geoId/29095 (Jackson County) will suppress geoId/2935648, geoId/2836000
# geoId/29097 (Jasper County) will suppress geoId/1837782
# geoId/29099 (Jefferson County) will suppress geoId/1341988
# geoId/29183 (St. Charles County) will suppress geoId/2964082
# geoId/29189 (St. Louis County) will suppress geoId/29510
# geoId/29221 (Washington County) will suppress geoId/2977416
# geoId/29225 (Webster County) will suppress geoId/2573895
# geoId/30031 (Gallatin County) will suppress geoId/4728540
# geoId/30063 (Missoula County) will suppress geoId/3050200
# geoId/31055 (Douglas County) will suppress geoId/0420050
# geoId/31109 (Lancaster County) will suppress geoId/0640130
# geoId/32003 (Clark County) will suppress geoId/3413150
# geoId/32005 (Douglas County) will suppress geoId/0420050
# geoId/32007 (Elko County) will suppress geoId/3222500
# geoId/33003 (Carroll County) will suppress geoId/1911080
# geoId/33005 (Cheshire County) will suppress geoId/0914160
# geoId/33009 (Grafton County) will suppress geoId/2526430
# geoId/33011 (Hillsborough County) will suppress geoId/0633798
# geoId/33013 (Merrimack County) will suppress geoId/3347540
# geoId/33019 (Sullivan County) will suppress geoId/3671993
# geoId/34005 (Burlington County) will suppress geoId/3408920, geoId/3709060
# geoId/34007 (Camden County) will suppress geoId/3410000
# geoId/34011 (Cumberland County) will suppress geoId/4420080
# geoId/34013 (Essex County) will suppress geoId/2426600
# geoId/34015 (Gloucester County) will suppress geoId/2526150
# geoId/34017 (Hudson County) will suppress geoId/3337940
# geoId/34023 (Middlesex County) will suppress geoId/3445900
# geoId/34025 (Monmouth County) will suppress geoId/4149550
# geoId/34027 (Morris County) will suppress geoId/1750491
# geoId/34031 (Passaic County) will suppress geoId/3456550
# geoId/34035 (Somerset County) will suppress geoId/3468370
# geoId/34037 (Sussex County) will suppress geoId/5578750
# geoId/34039 (Union County) will suppress geoId/3676056
# geoId/35028 (Los Alamos County) will suppress geoId/3542320
# geoId/35049 (Santa Fe County) will suppress geoId/3570500
# geoId/36001 (Albany County) will suppress geoId/3601000
# geoId/36017 (Chenango County) will suppress geoId/3615110
# geoId/36019 (Clinton County) will suppress geoId/2417900
# geoId/36023 (Cortland County) will suppress geoId/3618388
# geoId/36029 (Erie County) will suppress geoId/4224000
# geoId/36035 (Fulton County) will suppress geoId/2926182
# geoId/36045 (Jefferson County) will suppress geoId/1341988
# geoId/36051 (Livingston County) will suppress geoId/3440890
# geoId/36055 (Monroe County) will suppress geoId/2251410
# geoId/36065 (Oneida County) will suppress geoId/3654837
# geoId/36067 (Onondaga County) will suppress geoId/3654958
# geoId/36071 (Orange County) will suppress geoId/0653980
# geoId/36075 (Oswego County) will suppress geoId/1756887
# geoId/36077 (Otsego County) will suppress geoId/2749138
# geoId/36085 (Richmond County) will suppress geoId/5167000
# geoId/36087 (Rockland County) will suppress geoId/2557775
# geoId/36091 (Saratoga County) will suppress geoId/0670280
# geoId/36093 (Schenectady County) will suppress geoId/3665508
# geoId/36103 (Suffolk County) will suppress geoId/5176432
# geoId/36105 (Sullivan County) will suppress geoId/3671993
# geoId/36111 (Ulster County) will suppress geoId/3675935
# geoId/36117 (Wayne County) will suppress geoId/3477840
# geoId/36119 (Westchester County) will suppress geoId/1276075
# geoId/37013 (Beaufort County) will suppress geoId/4504690
# geoId/37019 (Brunswick County) will suppress geoId/3909680
# geoId/37023 (Burke County) will suppress geoId/5111464
# geoId/37027 (Caldwell County) will suppress geoId/1612250
# geoId/37031 (Carteret County) will suppress geoId/3410750
# geoId/37037 (Chatham County) will suppress geoId/1712684
# geoId/37051 (Cumberland County) will suppress geoId/4420080
# geoId/37057 (Davidson County) will suppress geoId/3716400
# geoId/37063 (Durham County) will suppress geoId/3719000
# geoId/37081 (Guilford County) will suppress geoId/0934950
# geoId/37089 (Henderson County) will suppress geoId/3730660
# geoId/37101 (Johnston County) will suppress geoId/4437720
# geoId/37107 (Lenoir County) will suppress geoId/3737760
# geoId/37117 (Martin County) will suppress geoId/4746240
# geoId/37125 (Moore County) will suppress geoId/4049200
# geoId/37135 (Orange County) will suppress geoId/0653980
# geoId/37151 (Randolph County) will suppress geoId/2555990
# geoId/37161 (Rutherford County) will suppress geoId/3465280
# geoId/37179 (Union County) will suppress geoId/3676056
# geoId/37189 (Watauga County) will suppress geoId/4876672
# geoId/37191 (Wayne County) will suppress geoId/3477840
# geoId/37195 (Wilson County) will suppress geoId/3774540
# geoId/38035 (Grand Forks County) will suppress geoId/3832060
# geoId/38059 (Morton County) will suppress geoId/1750621
# geoId/39005 (Ashland County) will suppress geoId/0602980, geoId/3902568
# geoId/39007 (Ashtabula County) will suppress geoId/3902638
# geoId/39009 (Athens County) will suppress geoId/3902736
# geoId/39013 (Belmont County) will suppress geoId/0605108
# geoId/39017 (Butler County) will suppress geoId/4210464
# geoId/39019 (Carroll County) will suppress geoId/1911080
# geoId/39023 (Clark County) will suppress geoId/3413150
# geoId/39025 (Clermont County) will suppress geoId/1212925
# geoId/39027 (Clinton County) will suppress geoId/2417900
# geoId/39031 (Coshocton County) will suppress geoId/3918868
# geoId/39039 (Defiance County) will suppress geoId/3921308
# geoId/39041 (Delaware County) will suppress geoId/3921434
# geoId/39045 (Fairfield County) will suppress geoId/0623182, geoId/3925970
# geoId/39049 (Franklin County) will suppress geoId/4727740, geoId/3928476
# geoId/39051 (Fulton County) will suppress geoId/2926182
# geoId/39061 (Hamilton County) will suppress geoId/3933012
# geoId/39067 (Harrison County) will suppress geoId/3933838
# geoId/39077 (Huron County) will suppress geoId/4631060
# geoId/39081 (Jefferson County) will suppress geoId/1341988
# geoId/39093 (Lorain County) will suppress geoId/3944856
# geoId/39101 (Marion County) will suppress geoId/3947754, geoId/1949485
# geoId/39103 (Medina County) will suppress geoId/3948790
# geoId/39113 (Montgomery County) will suppress geoId/3951716, geoId/0151000
# geoId/39123 (Ottawa County) will suppress geoId/1756926
# geoId/39127 (Perry County) will suppress geoId/1360340
# geoId/39133 (Portage County) will suppress geoId/2665560
# geoId/39139 (Richland County) will suppress geoId/5358235
# geoId/39143 (Sandusky County) will suppress geoId/3970380
# geoId/39145 (Scioto County) will suppress geoId/3970898
# geoId/39149 (Shelby County) will suppress geoId/3761200
# geoId/39153 (Summit County) will suppress geoId/3471430
# geoId/39155 (Trumbull County) will suppress geoId/0977270
# geoId/39159 (Union County) will suppress geoId/3676056
# geoId/39161 (Van Wert County) will suppress geoId/3979562
# geoId/39165 (Warren County) will suppress geoId/3980892, geoId/2684000
# geoId/39169 (Wayne County) will suppress geoId/3477840
# geoId/40005 (Atoka County) will suppress geoId/4702340
# geoId/40023 (Choctaw County) will suppress geoId/4014200
# geoId/40047 (Garfield County) will suppress geoId/3425770
# geoId/40101 (Muskogee County) will suppress geoId/4050050
# geoId/40111 (Okmulgee County) will suppress geoId/4055150
# geoId/40115 (Ottawa County) will suppress geoId/1756926
# geoId/40131 (Rogers County) will suppress geoId/0560410
# geoId/40133 (Seminole County) will suppress geoId/1264975
# geoId/40143 (Tulsa County) will suppress geoId/4075000
# geoId/40153 (Woodward County) will suppress geoId/4082150
# geoId/41001 (Baker County) will suppress geoId/2203985
# geoId/41003 (Benton County) will suppress geoId/0505290
# geoId/41019 (Douglas County) will suppress geoId/0420050
# geoId/41029 (Jackson County) will suppress geoId/2836000
# geoId/41031 (Jefferson County) will suppress geoId/1341988
# geoId/41047 (Marion County) will suppress geoId/1949485
# geoId/42019 (Butler County) will suppress geoId/4210464
# geoId/42029 (Chester County) will suppress geoId/4213208
# geoId/42033 (Clearfield County) will suppress geoId/4913850
# geoId/42037 (Columbia County) will suppress geoId/4215384
# geoId/42041 (Cumberland County) will suppress geoId/4420080
# geoId/42049 (Erie County) will suppress geoId/4224000
# geoId/42055 (Franklin County) will suppress geoId/4727740
# geoId/42057 (Fulton County) will suppress geoId/2926182
# geoId/42063 (Indiana County) will suppress geoId/4236816
# geoId/42065 (Jefferson County) will suppress geoId/1341988
# geoId/42069 (Lackawanna County) will suppress geoId/3640189
# geoId/42071 (Lancaster County) will suppress geoId/4241216, geoId/0640130
# geoId/42075 (Lebanon County) will suppress geoId/4242168, geoId/4741520
# geoId/42089 (Monroe County) will suppress geoId/2251410
# geoId/42091 (Montgomery County) will suppress geoId/0151000
# geoId/42095 (Northampton County) will suppress geoId/4254696, geoId/2546330
# geoId/42099 (Perry County) will suppress geoId/1360340
# geoId/42109 (Snyder County) will suppress geoId/4868624
# geoId/42111 (Somerset County) will suppress geoId/3468370
# geoId/42125 (Washington County) will suppress geoId/4281328
# geoId/42133 (York County) will suppress geoId/4287048
# geoId/44001 (Bristol County) will suppress geoId/4409280
# geoId/44003 (Kent County) will suppress geoId/5335415
# geoId/44005 (Newport County) will suppress geoId/4449960
# geoId/44007 (Providence County) will suppress geoId/4459000
# geoId/45001 (Abbeville County) will suppress geoId/2200100
# geoId/45003 (Aiken County) will suppress geoId/4500550
# geoId/45007 (Anderson County) will suppress geoId/1801468, geoId/4501360
# geoId/45013 (Beaufort County) will suppress geoId/4504690
# geoId/45015 (Berkeley County) will suppress geoId/0606000
# geoId/45019 (Charleston County) will suppress geoId/4513330
# geoId/45035 (Dorchester County) will suppress geoId/2517090
# geoId/45041 (Florence County) will suppress geoId/4525810
# geoId/45045 (Greenville County) will suppress geoId/4530850, geoId/3728080
# geoId/45047 (Greenwood County) will suppress geoId/4530895, geoId/1829898
# geoId/45053 (Jasper County) will suppress geoId/1837782
# geoId/45063 (Lexington County) will suppress geoId/4541335
# geoId/45071 (Newberry County) will suppress geoId/4549570
# geoId/45075 (Orangeburg County) will suppress geoId/4553080
# geoId/45079 (Richland County) will suppress geoId/5358235
# geoId/45083 (Spartanburg County) will suppress geoId/4568290
# geoId/45085 (Sumter County) will suppress geoId/4570405
# geoId/45089 (Williamsburg County) will suppress geoId/5186160
# geoId/45091 (York County) will suppress geoId/4287048
# geoId/46011 (Brookings County) will suppress geoId/4607580
# geoId/46099 (Minnehaha County) will suppress geoId/5346125
# geoId/46135 (Yankton County) will suppress geoId/4673060
# geoId/47001 (Anderson County) will suppress geoId/1801468
# geoId/47003 (Bedford County) will suppress geoId/4807132
# geoId/47011 (Bradley County) will suppress geoId/1707744
# geoId/47017 (Carroll County) will suppress geoId/1911080
# geoId/47025 (Claiborne County) will suppress geoId/2215605
# geoId/47035 (Cumberland County) will suppress geoId/4420080
# geoId/47037 (Davidson County) will suppress geoId/3716400
# geoId/47043 (Dickson County) will suppress geoId/4720620
# geoId/47045 (Dyer County) will suppress geoId/1819270
# geoId/47065 (Hamilton County) will suppress geoId/3933012
# geoId/47089 (Jefferson County) will suppress geoId/1341988
# geoId/47117 (Marshall County) will suppress geoId/4846776
# geoId/47123 (Monroe County) will suppress geoId/2251410
# geoId/47125 (Montgomery County) will suppress geoId/0151000
# geoId/47149 (Rutherford County) will suppress geoId/3465280
# geoId/47157 (Shelby County) will suppress geoId/3761200
# geoId/47163 (Sullivan County) will suppress geoId/3671993
# geoId/47165 (Sumner County) will suppress geoId/5368435
# geoId/47189 (Wilson County) will suppress geoId/3774540
# geoId/48001 (Anderson County) will suppress geoId/1801468
# geoId/48003 (Andrews County) will suppress geoId/4803216
# geoId/48021 (Bastrop County) will suppress geoId/4805864
# geoId/48027 (Bell County) will suppress geoId/0604870
# geoId/48037 (Bowie County) will suppress geoId/2408775
# geoId/48057 (Calhoun County) will suppress geoId/1312456
# geoId/48113 (Dallas County) will suppress geoId/4819000
# geoId/48121 (Denton County) will suppress geoId/4819972
# geoId/48141 (El Paso County) will suppress geoId/4824000
# geoId/48167 (Galveston County) will suppress geoId/4828068
# geoId/48177 (Gonzales County) will suppress geoId/2229850
# geoId/48185 (Grimes County) will suppress geoId/1933060
# geoId/48203 (Harrison County) will suppress geoId/3632402
# geoId/48209 (Hays County) will suppress geoId/2031100
# geoId/48213 (Henderson County) will suppress geoId/4833212
# geoId/48215 (Hidalgo County) will suppress geoId/4833560
# geoId/48223 (Hopkins County) will suppress geoId/2730140
# geoId/48227 (Howard County) will suppress geoId/5535950
# geoId/48241 (Jasper County) will suppress geoId/1837782
# geoId/48245 (Jefferson County) will suppress geoId/1341988
# geoId/48291 (Liberty County) will suppress geoId/2942032
# geoId/48303 (Lubbock County) will suppress geoId/4845000
# geoId/48325 (Medina County) will suppress geoId/3948790
# geoId/48329 (Midland County) will suppress geoId/4848072
# geoId/48339 (Montgomery County) will suppress geoId/0151000
# geoId/48347 (Nacogdoches County) will suppress geoId/4850256
# geoId/48361 (Orange County) will suppress geoId/4854132
# geoId/48367 (Parker County) will suppress geoId/0857630
# geoId/48371 (Pecos County) will suppress geoId/4856516
# geoId/48397 (Rockwall County) will suppress geoId/4862828
# geoId/48419 (Shelby County) will suppress geoId/3761200
# geoId/48441 (Taylor County) will suppress geoId/4871948, geoId/2679000
# geoId/48463 (Uvalde County) will suppress geoId/4874588
# geoId/48469 (Victoria County) will suppress geoId/4875428
# geoId/48471 (Walker County) will suppress geoId/2682960
# geoId/48493 (Wilson County) will suppress geoId/3774540
# geoId/49003 (Box Elder County) will suppress geoId/4606620
# geoId/49011 (Davis County) will suppress geoId/0618100
# geoId/49043 (Summit County) will suppress geoId/3471430
# geoId/49045 (Tooele County) will suppress geoId/4976680
# geoId/49053 (Washington County) will suppress geoId/4981960
# geoId/50001 (Addison County) will suppress geoId/1700243
# geoId/50003 (Bennington County) will suppress geoId/5004825
# geoId/50005 (Caledonia County) will suppress geoId/5511950
# geoId/50021 (Rutland County) will suppress geoId/5061300
# geoId/50025 (Windham County) will suppress geoId/0986790
# geoId/50027 (Windsor County) will suppress geoId/0885485
# geoId/51003 (Albemarle County) will suppress geoId/3700680
# geoId/51013 (Arlington County) will suppress geoId/5103000
# geoId/51019 (Bedford County) will suppress geoId/4807132
# geoId/51031 (Campbell County) will suppress geoId/0610345
# geoId/51035 (Carroll County) will suppress geoId/1911080
# geoId/51041 (Chesterfield County) will suppress geoId/2913600
# geoId/51047 (Culpeper County) will suppress geoId/5120752
# geoId/51059 (Fairfax County) will suppress geoId/5126496
# geoId/51069 (Frederick County) will suppress geoId/2430325
# geoId/51073 (Gloucester County) will suppress geoId/2526150
# geoId/51085 (Hanover County) will suppress geoId/4232448
# geoId/51111 (Lunenburg County) will suppress geoId/2537420
# geoId/51171 (Shenandoah County) will suppress geoId/2269225
# geoId/51199 (York County) will suppress geoId/4287048
# geoId/53005 (Benton County) will suppress geoId/0505290
# geoId/53011 (Clark County) will suppress geoId/3413150
# geoId/53017 (Douglas County) will suppress geoId/0420050
# geoId/53021 (Franklin County) will suppress geoId/4727740
# geoId/53031 (Jefferson County) will suppress geoId/1341988
# geoId/53045 (Mason County) will suppress geoId/3948188
# geoId/53061 (Snohomish County) will suppress geoId/5365170
# geoId/53063 (Spokane County) will suppress geoId/5367000
# geoId/53071 (Walla Walla County) will suppress geoId/5375775
# geoId/53075 (Whitman County) will suppress geoId/2579530
# geoId/53077 (Yakima County) will suppress geoId/5380010
# geoId/54003 (Berkeley County) will suppress geoId/0606000
# geoId/54005 (Boone County) will suppress geoId/3707080
# geoId/54033 (Harrison County) will suppress geoId/3632402
# geoId/54037 (Jefferson County) will suppress geoId/1341988
# geoId/54049 (Marion County) will suppress geoId/1949485
# geoId/54051 (Marshall County) will suppress geoId/4846776
# geoId/55019 (Clark County) will suppress geoId/3413150
# geoId/55031 (Douglas County) will suppress geoId/0420050
# geoId/55035 (Eau Claire County) will suppress geoId/5522300
# geoId/55039 (Fond du Lac County) will suppress geoId/5526275
# geoId/55045 (Green County) will suppress geoId/3931860
# geoId/55055 (Jefferson County) will suppress geoId/1341988
# geoId/55059 (Kenosha County) will suppress geoId/5539225
# geoId/55063 (La Crosse County) will suppress geoId/5540775
# geoId/55071 (Manitowoc County) will suppress geoId/5548500
# geoId/55075 (Marinette County) will suppress geoId/5549300
# geoId/55079 (Milwaukee County) will suppress geoId/5553000
# geoId/55081 (Monroe County) will suppress geoId/5553750
# geoId/55085 (Oneida County) will suppress geoId/3654837
# geoId/55097 (Portage County) will suppress geoId/2665560, geoId/5564100
# geoId/55101 (Racine County) will suppress geoId/5566000
# geoId/55117 (Sheboygan County) will suppress geoId/5572975
# geoId/55123 (Vernon County) will suppress geoId/0978250
# geoId/55133 (Waukesha County) will suppress geoId/5584250
# geoId/56005 (Campbell County) will suppress geoId/0610345
# geoId/56021 (Laramie County) will suppress geoId/5645050
# geoId/56033 (Sheridan County) will suppress geoId/5669845
# geoId/56037 (Sweetwater County) will suppress geoId/1270275

# %%
# @title List of safe counties CSV for copy/paste into Mixer store
for cid in sorted(safe_counties):
  cname_short = county2names[cid].replace(' County', '').replace(' county', '')
  print(f'{cid},{cname_short}')
# Out:
# geoId/01001,Autauga
# geoId/01005,Barbour
# geoId/01007,Bibb
# geoId/01009,Blount
# geoId/01011,Bullock
# geoId/01017,Chambers
# geoId/01019,Cherokee
# geoId/01021,Chilton
# geoId/01025,Clarke
# geoId/01029,Cleburne
# geoId/01031,Coffee
# geoId/01033,Colbert
# geoId/01035,Conecuh
# geoId/01037,Coosa
# geoId/01039,Covington
# geoId/01041,Crenshaw
# geoId/01045,Dale
# geoId/01047,Dallas
# geoId/01051,Elmore
# geoId/01053,Escambia
# geoId/01055,Etowah
# geoId/01057,Fayette
# geoId/01059,Franklin
# geoId/01063,Greene
# geoId/01065,Hale
# geoId/01067,Henry
# geoId/01069,Houston
# geoId/01071,Jackson
# geoId/01075,Lamar
# geoId/01077,Lauderdale
# geoId/01079,Lawrence
# geoId/01081,Lee
# geoId/01083,Limestone
# geoId/01085,Lowndes
# geoId/01087,Macon
# geoId/01091,Marengo
# geoId/01093,Marion
# geoId/01099,Monroe
# geoId/01103,Morgan
# geoId/01105,Perry
# geoId/01107,Pickens
# geoId/01109,Pike
# geoId/01111,Randolph
# geoId/01113,Russell
# geoId/01115,St. Clair
# geoId/01119,Sumter
# geoId/01123,Tallapoosa
# geoId/01129,Washington
# geoId/01131,Wilcox
# geoId/01133,Winston
# geoId/04001,Apache
# geoId/04003,Cochise
# geoId/04005,Coconino
# geoId/04007,Gila
# geoId/04011,Greenlee
# geoId/04012,La Paz
# geoId/04015,Mohave
# geoId/04017,Navajo
# geoId/04019,Pima
# geoId/04021,Pinal
# geoId/04023,Santa Cruz
# geoId/04025,Yavapai
# geoId/05001,Arkansas
# geoId/05003,Ashley
# geoId/05005,Baxter
# geoId/05011,Bradley
# geoId/05013,Calhoun
# geoId/05017,Chicot
# geoId/05021,Clay
# geoId/05023,Cleburne
# geoId/05025,Cleveland
# geoId/05027,Columbia
# geoId/05029,Conway
# geoId/05031,Craighead
# geoId/05033,Crawford
# geoId/05035,Crittenden
# geoId/05037,Cross
# geoId/05039,Dallas
# geoId/05041,Desha
# geoId/05043,Drew
# geoId/05045,Faulkner
# geoId/05047,Franklin
# geoId/05049,Fulton
# geoId/05051,Garland
# geoId/05053,Grant
# geoId/05055,Greene
# geoId/05057,Hempstead
# geoId/05059,Hot Spring
# geoId/05061,Howard
# geoId/05063,Independence
# geoId/05065,Izard
# geoId/05067,Jackson
# geoId/05071,Johnson
# geoId/05073,Lafayette
# geoId/05075,Lawrence
# geoId/05077,Lee
# geoId/05079,Lincoln
# geoId/05081,Little River
# geoId/05083,Logan
# geoId/05085,Lonoke
# geoId/05087,Madison
# geoId/05091,Miller
# geoId/05093,Mississippi
# geoId/05095,Monroe
# geoId/05097,Montgomery
# geoId/05099,Nevada
# geoId/05101,Newton
# geoId/05103,Ouachita
# geoId/05105,Perry
# geoId/05107,Phillips
# geoId/05109,Pike
# geoId/05111,Poinsett
# geoId/05113,Polk
# geoId/05115,Pope
# geoId/05117,Prairie
# geoId/05119,Pulaski
# geoId/05121,Randolph
# geoId/05123,St. Francis
# geoId/05125,Saline
# geoId/05127,Scott
# geoId/05129,Searcy
# geoId/05133,Sevier
# geoId/05135,Sharp
# geoId/05137,Stone
# geoId/05139,Union
# geoId/05141,Van Buren
# geoId/05143,Washington
# geoId/05145,White
# geoId/05147,Woodruff
# geoId/05149,Yell
# geoId/06003,Alpine
# geoId/06005,Amador
# geoId/06009,Calaveras
# geoId/06011,Colusa
# geoId/06013,Contra Costa
# geoId/06015,Del Norte
# geoId/06021,Glenn
# geoId/06023,Humboldt
# geoId/06027,Inyo
# geoId/06029,Kern
# geoId/06031,Kings
# geoId/06033,Lake
# geoId/06035,Lassen
# geoId/06041,Marin
# geoId/06043,Mariposa
# geoId/06045,Mendocino
# geoId/06049,Modoc
# geoId/06051,Mono
# geoId/06057,Nevada
# geoId/06061,Placer
# geoId/06063,Plumas
# geoId/06075,San Francisco
# geoId/06077,San Joaquin
# geoId/06089,Shasta
# geoId/06091,Sierra
# geoId/06093,Siskiyou
# geoId/06095,Solano
# geoId/06099,Stanislaus
# geoId/06101,Sutter
# geoId/06103,Tehama
# geoId/06105,Trinity
# geoId/06109,Tuolumne
# geoId/06113,Yolo
# geoId/06115,Yuba
# geoId/08001,Adams
# geoId/08003,Alamosa
# geoId/08005,Arapahoe
# geoId/08007,Archuleta
# geoId/08009,Baca
# geoId/08011,Bent
# geoId/08015,Chaffee
# geoId/08017,Cheyenne
# geoId/08019,Clear Creek
# geoId/08021,Conejos
# geoId/08023,Costilla
# geoId/08025,Crowley
# geoId/08027,Custer
# geoId/08029,Delta
# geoId/08033,Dolores
# geoId/08039,Elbert
# geoId/08043,Fremont
# geoId/08047,Gilpin
# geoId/08049,Grand
# geoId/08051,Gunnison
# geoId/08053,Hinsdale
# geoId/08055,Huerfano
# geoId/08057,Jackson
# geoId/08061,Kiowa
# geoId/08063,Kit Carson
# geoId/08065,Lake
# geoId/08069,Larimer
# geoId/08071,Las Animas
# geoId/08073,Lincoln
# geoId/08075,Logan
# geoId/08077,Mesa
# geoId/08079,Mineral
# geoId/08081,Moffat
# geoId/08083,Montezuma
# geoId/08087,Morgan
# geoId/08089,Otero
# geoId/08091,Ouray
# geoId/08093,Park
# geoId/08095,Phillips
# geoId/08097,Pitkin
# geoId/08099,Prowers
# geoId/08103,Rio Blanco
# geoId/08105,Rio Grande
# geoId/08107,Routt
# geoId/08109,Saguache
# geoId/08111,San Juan
# geoId/08113,San Miguel
# geoId/08115,Sedgwick
# geoId/08119,Teller
# geoId/08121,Washington
# geoId/08123,Weld
# geoId/08125,Yuma
# geoId/09005,Litchfield
# geoId/12005,Bay
# geoId/12007,Bradford
# geoId/12009,Brevard
# geoId/12011,Broward
# geoId/12013,Calhoun
# geoId/12015,Charlotte
# geoId/12021,Collier
# geoId/12023,Columbia
# geoId/12027,DeSoto
# geoId/12029,Dixie
# geoId/12031,Duval
# geoId/12033,Escambia
# geoId/12035,Flagler
# geoId/12037,Franklin
# geoId/12041,Gilchrist
# geoId/12043,Glades
# geoId/12045,Gulf
# geoId/12047,Hamilton
# geoId/12049,Hardee
# geoId/12051,Hendry
# geoId/12059,Holmes
# geoId/12061,Indian River
# geoId/12063,Jackson
# geoId/12065,Jefferson
# geoId/12067,Lafayette
# geoId/12069,Lake
# geoId/12071,Lee
# geoId/12073,Leon
# geoId/12075,Levy
# geoId/12077,Liberty
# geoId/12079,Madison
# geoId/12081,Manatee
# geoId/12086,Miami-Dade
# geoId/12089,Nassau
# geoId/12091,Okaloosa
# geoId/12093,Okeechobee
# geoId/12097,Osceola
# geoId/12099,Palm Beach
# geoId/12103,Pinellas
# geoId/12105,Polk
# geoId/12107,Putnam
# geoId/12109,St. Johns
# geoId/12111,St. Lucie
# geoId/12121,Suwannee
# geoId/12123,Taylor
# geoId/12125,Union
# geoId/12127,Volusia
# geoId/12129,Wakulla
# geoId/12131,Walton
# geoId/12133,Washington
# geoId/13001,Appling
# geoId/13003,Atkinson
# geoId/13005,Bacon
# geoId/13007,Baker
# geoId/13011,Banks
# geoId/13013,Barrow
# geoId/13017,Ben Hill
# geoId/13019,Berrien
# geoId/13021,Bibb
# geoId/13023,Bleckley
# geoId/13025,Brantley
# geoId/13027,Brooks
# geoId/13029,Bryan
# geoId/13031,Bulloch
# geoId/13033,Burke
# geoId/13035,Butts
# geoId/13037,Calhoun
# geoId/13039,Camden
# geoId/13043,Candler
# geoId/13047,Catoosa
# geoId/13049,Charlton
# geoId/13053,Chattahoochee
# geoId/13055,Chattooga
# geoId/13057,Cherokee
# geoId/13059,Clarke
# geoId/13061,Clay
# geoId/13065,Clinch
# geoId/13067,Cobb
# geoId/13069,Coffee
# geoId/13071,Colquitt
# geoId/13075,Cook
# geoId/13079,Crawford
# geoId/13081,Crisp
# geoId/13083,Dade
# geoId/13085,Dawson
# geoId/13091,Dodge
# geoId/13093,Dooly
# geoId/13095,Dougherty
# geoId/13099,Early
# geoId/13101,Echols
# geoId/13105,Elbert
# geoId/13107,Emanuel
# geoId/13109,Evans
# geoId/13111,Fannin
# geoId/13113,Fayette
# geoId/13115,Floyd
# geoId/13117,Forsyth
# geoId/13119,Franklin
# geoId/13123,Gilmer
# geoId/13125,Glascock
# geoId/13127,Glynn
# geoId/13129,Gordon
# geoId/13131,Grady
# geoId/13133,Greene
# geoId/13135,Gwinnett
# geoId/13137,Habersham
# geoId/13139,Hall
# geoId/13141,Hancock
# geoId/13143,Haralson
# geoId/13145,Harris
# geoId/13147,Hart
# geoId/13149,Heard
# geoId/13151,Henry
# geoId/13153,Houston
# geoId/13155,Irwin
# geoId/13157,Jackson
# geoId/13159,Jasper
# geoId/13161,Jeff Davis
# geoId/13165,Jenkins
# geoId/13167,Johnson
# geoId/13169,Jones
# geoId/13171,Lamar
# geoId/13173,Lanier
# geoId/13175,Laurens
# geoId/13177,Lee
# geoId/13181,Lincoln
# geoId/13183,Long
# geoId/13185,Lowndes
# geoId/13187,Lumpkin
# geoId/13189,McDuffie
# geoId/13191,McIntosh
# geoId/13193,Macon
# geoId/13195,Madison
# geoId/13197,Marion
# geoId/13199,Meriwether
# geoId/13201,Miller
# geoId/13209,Montgomery
# geoId/13211,Morgan
# geoId/13213,Murray
# geoId/13215,Muscogee
# geoId/13219,Oconee
# geoId/13221,Oglethorpe
# geoId/13223,Paulding
# geoId/13225,Peach
# geoId/13227,Pickens
# geoId/13229,Pierce
# geoId/13231,Pike
# geoId/13233,Polk
# geoId/13235,Pulaski
# geoId/13237,Putnam
# geoId/13239,Quitman
# geoId/13241,Rabun
# geoId/13243,Randolph
# geoId/13245,Richmond
# geoId/13247,Rockdale
# geoId/13249,Schley
# geoId/13251,Screven
# geoId/13253,Seminole
# geoId/13255,Spalding
# geoId/13257,Stephens
# geoId/13259,Stewart
# geoId/13261,Sumter
# geoId/13263,Talbot
# geoId/13265,Taliaferro
# geoId/13267,Tattnall
# geoId/13269,Taylor
# geoId/13271,Telfair
# geoId/13273,Terrell
# geoId/13275,Thomas
# geoId/13277,Tift
# geoId/13279,Toombs
# geoId/13281,Towns
# geoId/13283,Treutlen
# geoId/13285,Troup
# geoId/13287,Turner
# geoId/13289,Twiggs
# geoId/13291,Union
# geoId/13293,Upson
# geoId/13297,Walton
# geoId/13299,Ware
# geoId/13301,Warren
# geoId/13303,Washington
# geoId/13305,Wayne
# geoId/13307,Webster
# geoId/13309,Wheeler
# geoId/13311,White
# geoId/13313,Whitfield
# geoId/13315,Wilcox
# geoId/13317,Wilkes
# geoId/13319,Wilkinson
# geoId/15001,Hawaii
# geoId/15005,Kalawao
# geoId/15007,Kauai
# geoId/15009,Maui
# geoId/16003,Adams
# geoId/16005,Bannock
# geoId/16007,Bear Lake
# geoId/16009,Benewah
# geoId/16011,Bingham
# geoId/16013,Blaine
# geoId/16015,Boise
# geoId/16017,Bonner
# geoId/16019,Bonneville
# geoId/16021,Boundary
# geoId/16023,Butte
# geoId/16025,Camas
# geoId/16029,Caribou
# geoId/16031,Cassia
# geoId/16033,Clark
# geoId/16035,Clearwater
# geoId/16037,Custer
# geoId/16039,Elmore
# geoId/16041,Franklin
# geoId/16043,Fremont
# geoId/16045,Gem
# geoId/16047,Gooding
# geoId/16049,Idaho
# geoId/16055,Kootenai
# geoId/16057,Latah
# geoId/16059,Lemhi
# geoId/16061,Lewis
# geoId/16063,Lincoln
# geoId/16065,Madison
# geoId/16067,Minidoka
# geoId/16069,Nez Perce
# geoId/16071,Oneida
# geoId/16073,Owyhee
# geoId/16075,Payette
# geoId/16077,Power
# geoId/16079,Shoshone
# geoId/16081,Teton
# geoId/16087,Washington
# geoId/17001,Adams
# geoId/17003,Alexander
# geoId/17005,Bond
# geoId/17009,Brown
# geoId/17011,Bureau
# geoId/17013,Calhoun
# geoId/17017,Cass
# geoId/17021,Christian
# geoId/17023,Clark
# geoId/17025,Clay
# geoId/17027,Clinton
# geoId/17029,Coles
# geoId/17031,Cook
# geoId/17033,Crawford
# geoId/17035,Cumberland
# geoId/17039,De Witt
# geoId/17043,DuPage
# geoId/17045,Edgar
# geoId/17047,Edwards
# geoId/17051,Fayette
# geoId/17053,Ford
# geoId/17055,Franklin
# geoId/17059,Gallatin
# geoId/17061,Greene
# geoId/17063,Grundy
# geoId/17065,Hamilton
# geoId/17067,Hancock
# geoId/17069,Hardin
# geoId/17071,Henderson
# geoId/17073,Henry
# geoId/17075,Iroquois
# geoId/17077,Jackson
# geoId/17079,Jasper
# geoId/17083,Jersey
# geoId/17085,Jo Daviess
# geoId/17087,Johnson
# geoId/17089,Kane
# geoId/17095,Knox
# geoId/17097,Lake
# geoId/17099,LaSalle
# geoId/17101,Lawrence
# geoId/17103,Lee
# geoId/17107,Logan
# geoId/17109,McDonough
# geoId/17117,Macoupin
# geoId/17119,Madison
# geoId/17123,Marshall
# geoId/17125,Mason
# geoId/17127,Massac
# geoId/17129,Menard
# geoId/17131,Mercer
# geoId/17133,Monroe
# geoId/17137,Morgan
# geoId/17139,Moultrie
# geoId/17141,Ogle
# geoId/17145,Perry
# geoId/17147,Piatt
# geoId/17149,Pike
# geoId/17151,Pope
# geoId/17153,Pulaski
# geoId/17155,Putnam
# geoId/17157,Randolph
# geoId/17159,Richland
# geoId/17163,St. Clair
# geoId/17165,Saline
# geoId/17167,Sangamon
# geoId/17169,Schuyler
# geoId/17171,Scott
# geoId/17173,Shelby
# geoId/17175,Stark
# geoId/17177,Stephenson
# geoId/17179,Tazewell
# geoId/17181,Union
# geoId/17187,Warren
# geoId/17189,Washington
# geoId/17191,Wayne
# geoId/17193,White
# geoId/17195,Whiteside
# geoId/17197,Will
# geoId/17199,Williamson
# geoId/17201,Winnebago
# geoId/17203,Woodford
# geoId/18001,Adams
# geoId/18005,Bartholomew
# geoId/18007,Benton
# geoId/18009,Blackford
# geoId/18013,Brown
# geoId/18017,Cass
# geoId/18021,Clay
# geoId/18023,Clinton
# geoId/18025,Crawford
# geoId/18027,Daviess
# geoId/18029,Dearborn
# geoId/18031,Decatur
# geoId/18035,Delaware
# geoId/18037,Dubois
# geoId/18041,Fayette
# geoId/18043,Floyd
# geoId/18045,Fountain
# geoId/18047,Franklin
# geoId/18051,Gibson
# geoId/18053,Grant
# geoId/18055,Greene
# geoId/18059,Hancock
# geoId/18063,Hendricks
# geoId/18065,Henry
# geoId/18071,Jackson
# geoId/18075,Jay
# geoId/18081,Johnson
# geoId/18083,Knox
# geoId/18085,Kosciusko
# geoId/18089,Lake
# geoId/18091,LaPorte
# geoId/18093,Lawrence
# geoId/18101,Martin
# geoId/18103,Miami
# geoId/18107,Montgomery
# geoId/18109,Morgan
# geoId/18111,Newton
# geoId/18113,Noble
# geoId/18115,Ohio
# geoId/18117,Orange
# geoId/18119,Owen
# geoId/18121,Parke
# geoId/18123,Perry
# geoId/18125,Pike
# geoId/18127,Porter
# geoId/18129,Posey
# geoId/18131,Pulaski
# geoId/18133,Putnam
# geoId/18135,Randolph
# geoId/18137,Ripley
# geoId/18139,Rush
# geoId/18143,Scott
# geoId/18149,Starke
# geoId/18151,Steuben
# geoId/18155,Switzerland
# geoId/18157,Tippecanoe
# geoId/18159,Tipton
# geoId/18161,Union
# geoId/18163,Vanderburgh
# geoId/18167,Vigo
# geoId/18171,Warren
# geoId/18173,Warrick
# geoId/18179,Wells
# geoId/18181,White
# geoId/18183,Whitley
# geoId/19001,Adair
# geoId/19003,Adams
# geoId/19005,Allamakee
# geoId/19007,Appanoose
# geoId/19009,Audubon
# geoId/19011,Benton
# geoId/19013,Black Hawk
# geoId/19017,Bremer
# geoId/19019,Buchanan
# geoId/19021,Buena Vista
# geoId/19025,Calhoun
# geoId/19029,Cass
# geoId/19031,Cedar
# geoId/19033,Cerro Gordo
# geoId/19035,Cherokee
# geoId/19037,Chickasaw
# geoId/19039,Clarke
# geoId/19041,Clay
# geoId/19043,Clayton
# geoId/19047,Crawford
# geoId/19049,Dallas
# geoId/19051,Davis
# geoId/19053,Decatur
# geoId/19055,Delaware
# geoId/19057,Des Moines
# geoId/19059,Dickinson
# geoId/19063,Emmet
# geoId/19065,Fayette
# geoId/19067,Floyd
# geoId/19069,Franklin
# geoId/19071,Fremont
# geoId/19073,Greene
# geoId/19075,Grundy
# geoId/19077,Guthrie
# geoId/19079,Hamilton
# geoId/19081,Hancock
# geoId/19083,Hardin
# geoId/19085,Harrison
# geoId/19087,Henry
# geoId/19089,Howard
# geoId/19091,Humboldt
# geoId/19093,Ida
# geoId/19095,Iowa
# geoId/19097,Jackson
# geoId/19103,Johnson
# geoId/19105,Jones
# geoId/19107,Keokuk
# geoId/19109,Kossuth
# geoId/19111,Lee
# geoId/19113,Linn
# geoId/19115,Louisa
# geoId/19117,Lucas
# geoId/19119,Lyon
# geoId/19121,Madison
# geoId/19123,Mahaska
# geoId/19125,Marion
# geoId/19129,Mills
# geoId/19131,Mitchell
# geoId/19133,Monona
# geoId/19135,Monroe
# geoId/19137,Montgomery
# geoId/19141,O'Brien
# geoId/19143,Osceola
# geoId/19145,Page
# geoId/19147,Palo Alto
# geoId/19149,Plymouth
# geoId/19151,Pocahontas
# geoId/19153,Polk
# geoId/19155,Pottawattamie
# geoId/19157,Poweshiek
# geoId/19159,Ringgold
# geoId/19161,Sac
# geoId/19163,Scott
# geoId/19165,Shelby
# geoId/19167,Sioux
# geoId/19169,Story
# geoId/19171,Tama
# geoId/19173,Taylor
# geoId/19175,Union
# geoId/19177,Van Buren
# geoId/19179,Wapello
# geoId/19181,Warren
# geoId/19183,Washington
# geoId/19185,Wayne
# geoId/19189,Winnebago
# geoId/19191,Winneshiek
# geoId/19195,Worth
# geoId/19197,Wright
# geoId/20001,Allen
# geoId/20003,Anderson
# geoId/20007,Barber
# geoId/20009,Barton
# geoId/20011,Bourbon
# geoId/20013,Brown
# geoId/20017,Chase
# geoId/20019,Chautauqua
# geoId/20021,Cherokee
# geoId/20023,Cheyenne
# geoId/20025,Clark
# geoId/20027,Clay
# geoId/20029,Cloud
# geoId/20031,Coffey
# geoId/20033,Comanche
# geoId/20035,Cowley
# geoId/20037,Crawford
# geoId/20039,Decatur
# geoId/20041,Dickinson
# geoId/20043,Doniphan
# geoId/20047,Edwards
# geoId/20049,Elk
# geoId/20051,Ellis
# geoId/20053,Ellsworth
# geoId/20055,Finney
# geoId/20057,Ford
# geoId/20059,Franklin
# geoId/20061,Geary
# geoId/20063,Gove
# geoId/20065,Graham
# geoId/20067,Grant
# geoId/20069,Gray
# geoId/20071,Greeley
# geoId/20073,Greenwood
# geoId/20075,Hamilton
# geoId/20077,Harper
# geoId/20081,Haskell
# geoId/20083,Hodgeman
# geoId/20085,Jackson
# geoId/20089,Jewell
# geoId/20091,Johnson
# geoId/20093,Kearny
# geoId/20095,Kingman
# geoId/20097,Kiowa
# geoId/20099,Labette
# geoId/20101,Lane
# geoId/20105,Lincoln
# geoId/20107,Linn
# geoId/20109,Logan
# geoId/20111,Lyon
# geoId/20115,Marion
# geoId/20117,Marshall
# geoId/20119,Meade
# geoId/20121,Miami
# geoId/20123,Mitchell
# geoId/20125,Montgomery
# geoId/20127,Morris
# geoId/20129,Morton
# geoId/20131,Nemaha
# geoId/20135,Ness
# geoId/20137,Norton
# geoId/20139,Osage
# geoId/20141,Osborne
# geoId/20143,Ottawa
# geoId/20145,Pawnee
# geoId/20147,Phillips
# geoId/20149,Pottawatomie
# geoId/20151,Pratt
# geoId/20153,Rawlins
# geoId/20155,Reno
# geoId/20157,Republic
# geoId/20159,Rice
# geoId/20161,Riley
# geoId/20163,Rooks
# geoId/20165,Rush
# geoId/20167,Russell
# geoId/20169,Saline
# geoId/20171,Scott
# geoId/20173,Sedgwick
# geoId/20175,Seward
# geoId/20179,Sheridan
# geoId/20181,Sherman
# geoId/20183,Smith
# geoId/20185,Stafford
# geoId/20187,Stanton
# geoId/20189,Stevens
# geoId/20193,Thomas
# geoId/20195,Trego
# geoId/20197,Wabaunsee
# geoId/20199,Wallace
# geoId/20201,Washington
# geoId/20203,Wichita
# geoId/20205,Wilson
# geoId/20207,Woodson
# geoId/21001,Adair
# geoId/21003,Allen
# geoId/21005,Anderson
# geoId/21007,Ballard
# geoId/21009,Barren
# geoId/21013,Bell
# geoId/21017,Bourbon
# geoId/21019,Boyd
# geoId/21021,Boyle
# geoId/21023,Bracken
# geoId/21025,Breathitt
# geoId/21027,Breckinridge
# geoId/21029,Bullitt
# geoId/21031,Butler
# geoId/21033,Caldwell
# geoId/21035,Calloway
# geoId/21039,Carlisle
# geoId/21043,Carter
# geoId/21045,Casey
# geoId/21047,Christian
# geoId/21051,Clay
# geoId/21053,Clinton
# geoId/21055,Crittenden
# geoId/21057,Cumberland
# geoId/21059,Daviess
# geoId/21061,Edmonson
# geoId/21063,Elliott
# geoId/21065,Estill
# geoId/21067,Fayette
# geoId/21069,Fleming
# geoId/21071,Floyd
# geoId/21075,Fulton
# geoId/21077,Gallatin
# geoId/21079,Garrard
# geoId/21081,Grant
# geoId/21083,Graves
# geoId/21085,Grayson
# geoId/21087,Green
# geoId/21089,Greenup
# geoId/21091,Hancock
# geoId/21093,Hardin
# geoId/21095,Harlan
# geoId/21097,Harrison
# geoId/21099,Hart
# geoId/21103,Henry
# geoId/21105,Hickman
# geoId/21109,Jackson
# geoId/21113,Jessamine
# geoId/21115,Johnson
# geoId/21117,Kenton
# geoId/21119,Knott
# geoId/21121,Knox
# geoId/21123,LaRue
# geoId/21127,Lawrence
# geoId/21129,Lee
# geoId/21131,Leslie
# geoId/21133,Letcher
# geoId/21135,Lewis
# geoId/21137,Lincoln
# geoId/21139,Livingston
# geoId/21141,Logan
# geoId/21143,Lyon
# geoId/21145,McCracken
# geoId/21147,McCreary
# geoId/21149,McLean
# geoId/21151,Madison
# geoId/21153,Magoffin
# geoId/21155,Marion
# geoId/21161,Mason
# geoId/21163,Meade
# geoId/21165,Menifee
# geoId/21167,Mercer
# geoId/21169,Metcalfe
# geoId/21171,Monroe
# geoId/21173,Montgomery
# geoId/21175,Morgan
# geoId/21177,Muhlenberg
# geoId/21179,Nelson
# geoId/21181,Nicholas
# geoId/21183,Ohio
# geoId/21185,Oldham
# geoId/21187,Owen
# geoId/21189,Owsley
# geoId/21191,Pendleton
# geoId/21195,Pike
# geoId/21197,Powell
# geoId/21199,Pulaski
# geoId/21201,Robertson
# geoId/21203,Rockcastle
# geoId/21205,Rowan
# geoId/21207,Russell
# geoId/21209,Scott
# geoId/21213,Simpson
# geoId/21217,Taylor
# geoId/21219,Todd
# geoId/21221,Trigg
# geoId/21223,Trimble
# geoId/21225,Union
# geoId/21229,Washington
# geoId/21231,Wayne
# geoId/21233,Webster
# geoId/21235,Whitley
# geoId/21237,Wolfe
# geoId/21239,Woodford
# geoId/23001,Androscoggin
# geoId/23003,Aroostook
# geoId/23007,Franklin
# geoId/23009,Hancock
# geoId/23011,Kennebec
# geoId/23013,Knox
# geoId/23015,Lincoln
# geoId/23019,Penobscot
# geoId/23021,Piscataquis
# geoId/23023,Sagadahoc
# geoId/23027,Waldo
# geoId/23029,Washington
# geoId/24001,Allegany
# geoId/24003,Anne Arundel
# geoId/24009,Calvert
# geoId/24011,Caroline
# geoId/24015,Cecil
# geoId/24017,Charles
# geoId/24019,Dorchester
# geoId/24023,Garrett
# geoId/24025,Harford
# geoId/24029,Kent
# geoId/24033,Prince George's
# geoId/24035,Queen Anne's
# geoId/24037,St. Mary's
# geoId/24041,Talbot
# geoId/24043,Washington
# geoId/24045,Wicomico
# geoId/24047,Worcester
# geoId/25003,Berkshire
# geoId/25007,Dukes
# geoId/25013,Hampden
# geoId/25015,Hampshire
# geoId/26001,Alcona
# geoId/26003,Alger
# geoId/26005,Allegan
# geoId/26009,Antrim
# geoId/26011,Arenac
# geoId/26013,Baraga
# geoId/26015,Barry
# geoId/26017,Bay
# geoId/26019,Benzie
# geoId/26021,Berrien
# geoId/26023,Branch
# geoId/26027,Cass
# geoId/26029,Charlevoix
# geoId/26031,Cheboygan
# geoId/26033,Chippewa
# geoId/26035,Clare
# geoId/26039,Crawford
# geoId/26041,Delta
# geoId/26045,Eaton
# geoId/26047,Emmet
# geoId/26049,Genesee
# geoId/26051,Gladwin
# geoId/26053,Gogebic
# geoId/26055,Grand Traverse
# geoId/26057,Gratiot
# geoId/26061,Houghton
# geoId/26065,Ingham
# geoId/26069,Iosco
# geoId/26071,Iron
# geoId/26073,Isabella
# geoId/26079,Kalkaska
# geoId/26083,Keweenaw
# geoId/26085,Lake
# geoId/26087,Lapeer
# geoId/26089,Leelanau
# geoId/26091,Lenawee
# geoId/26095,Luce
# geoId/26097,Mackinac
# geoId/26101,Manistee
# geoId/26105,Mason
# geoId/26107,Mecosta
# geoId/26109,Menominee
# geoId/26113,Missaukee
# geoId/26117,Montcalm
# geoId/26119,Montmorency
# geoId/26123,Newaygo
# geoId/26127,Oceana
# geoId/26129,Ogemaw
# geoId/26131,Ontonagon
# geoId/26133,Osceola
# geoId/26135,Oscoda
# geoId/26141,Presque Isle
# geoId/26143,Roscommon
# geoId/26147,St. Clair
# geoId/26149,St. Joseph
# geoId/26151,Sanilac
# geoId/26153,Schoolcraft
# geoId/26155,Shiawassee
# geoId/26157,Tuscola
# geoId/26161,Washtenaw
# geoId/26165,Wexford
# geoId/27001,Aitkin
# geoId/27005,Becker
# geoId/27007,Beltrami
# geoId/27011,Big Stone
# geoId/27013,Blue Earth
# geoId/27015,Brown
# geoId/27017,Carlton
# geoId/27021,Cass
# geoId/27023,Chippewa
# geoId/27025,Chisago
# geoId/27029,Clearwater
# geoId/27031,Cook
# geoId/27033,Cottonwood
# geoId/27035,Crow Wing
# geoId/27037,Dakota
# geoId/27039,Dodge
# geoId/27043,Faribault
# geoId/27047,Freeborn
# geoId/27049,Goodhue
# geoId/27051,Grant
# geoId/27053,Hennepin
# geoId/27055,Houston
# geoId/27057,Hubbard
# geoId/27059,Isanti
# geoId/27061,Itasca
# geoId/27063,Jackson
# geoId/27065,Kanabec
# geoId/27067,Kandiyohi
# geoId/27069,Kittson
# geoId/27071,Koochiching
# geoId/27073,Lac qui Parle
# geoId/27075,Lake
# geoId/27077,Lake of the Woods
# geoId/27079,Le Sueur
# geoId/27081,Lincoln
# geoId/27083,Lyon
# geoId/27085,McLeod
# geoId/27087,Mahnomen
# geoId/27089,Marshall
# geoId/27093,Meeker
# geoId/27095,Mille Lacs
# geoId/27097,Morrison
# geoId/27099,Mower
# geoId/27101,Murray
# geoId/27103,Nicollet
# geoId/27105,Nobles
# geoId/27107,Norman
# geoId/27109,Olmsted
# geoId/27111,Otter Tail
# geoId/27113,Pennington
# geoId/27115,Pine
# geoId/27117,Pipestone
# geoId/27119,Polk
# geoId/27121,Pope
# geoId/27125,Red Lake
# geoId/27127,Redwood
# geoId/27129,Renville
# geoId/27131,Rice
# geoId/27133,Rock
# geoId/27135,Roseau
# geoId/27137,St. Louis
# geoId/27139,Scott
# geoId/27141,Sherburne
# geoId/27143,Sibley
# geoId/27145,Stearns
# geoId/27147,Steele
# geoId/27149,Stevens
# geoId/27151,Swift
# geoId/27153,Todd
# geoId/27155,Traverse
# geoId/27157,Wabasha
# geoId/27159,Wadena
# geoId/27161,Waseca
# geoId/27163,Washington
# geoId/27165,Watonwan
# geoId/27167,Wilkin
# geoId/27173,Yellow Medicine
# geoId/28001,Adams
# geoId/28003,Alcorn
# geoId/28005,Amite
# geoId/28007,Attala
# geoId/28009,Benton
# geoId/28013,Calhoun
# geoId/28015,Carroll
# geoId/28017,Chickasaw
# geoId/28019,Choctaw
# geoId/28021,Claiborne
# geoId/28023,Clarke
# geoId/28025,Clay
# geoId/28027,Coahoma
# geoId/28029,Copiah
# geoId/28031,Covington
# geoId/28035,Forrest
# geoId/28037,Franklin
# geoId/28039,George
# geoId/28041,Greene
# geoId/28045,Hancock
# geoId/28049,Hinds
# geoId/28051,Holmes
# geoId/28053,Humphreys
# geoId/28055,Issaquena
# geoId/28057,Itawamba
# geoId/28059,Jackson
# geoId/28061,Jasper
# geoId/28063,Jefferson
# geoId/28065,Jefferson Davis
# geoId/28067,Jones
# geoId/28069,Kemper
# geoId/28071,Lafayette
# geoId/28073,Lamar
# geoId/28075,Lauderdale
# geoId/28077,Lawrence
# geoId/28079,Leake
# geoId/28081,Lee
# geoId/28083,Leflore
# geoId/28085,Lincoln
# geoId/28087,Lowndes
# geoId/28091,Marion
# geoId/28095,Monroe
# geoId/28097,Montgomery
# geoId/28099,Neshoba
# geoId/28101,Newton
# geoId/28103,Noxubee
# geoId/28105,Oktibbeha
# geoId/28107,Panola
# geoId/28111,Perry
# geoId/28113,Pike
# geoId/28115,Pontotoc
# geoId/28117,Prentiss
# geoId/28119,Quitman
# geoId/28121,Rankin
# geoId/28123,Scott
# geoId/28125,Sharkey
# geoId/28127,Simpson
# geoId/28129,Smith
# geoId/28131,Stone
# geoId/28133,Sunflower
# geoId/28135,Tallahatchie
# geoId/28137,Tate
# geoId/28139,Tippah
# geoId/28141,Tishomingo
# geoId/28143,Tunica
# geoId/28145,Union
# geoId/28147,Walthall
# geoId/28149,Warren
# geoId/28151,Washington
# geoId/28153,Wayne
# geoId/28155,Webster
# geoId/28157,Wilkinson
# geoId/28159,Winston
# geoId/28161,Yalobusha
# geoId/28163,Yazoo
# geoId/29001,Adair
# geoId/29003,Andrew
# geoId/29005,Atchison
# geoId/29007,Audrain
# geoId/29009,Barry
# geoId/29011,Barton
# geoId/29013,Bates
# geoId/29015,Benton
# geoId/29017,Bollinger
# geoId/29021,Buchanan
# geoId/29025,Caldwell
# geoId/29029,Camden
# geoId/29033,Carroll
# geoId/29035,Carter
# geoId/29037,Cass
# geoId/29039,Cedar
# geoId/29041,Chariton
# geoId/29043,Christian
# geoId/29045,Clark
# geoId/29049,Clinton
# geoId/29051,Cole
# geoId/29053,Cooper
# geoId/29055,Crawford
# geoId/29057,Dade
# geoId/29059,Dallas
# geoId/29061,Daviess
# geoId/29063,DeKalb
# geoId/29067,Douglas
# geoId/29069,Dunklin
# geoId/29073,Gasconade
# geoId/29075,Gentry
# geoId/29077,Greene
# geoId/29079,Grundy
# geoId/29081,Harrison
# geoId/29083,Henry
# geoId/29085,Hickory
# geoId/29087,Holt
# geoId/29089,Howard
# geoId/29093,Iron
# geoId/29101,Johnson
# geoId/29103,Knox
# geoId/29105,Laclede
# geoId/29107,Lafayette
# geoId/29109,Lawrence
# geoId/29111,Lewis
# geoId/29113,Lincoln
# geoId/29115,Linn
# geoId/29117,Livingston
# geoId/29119,McDonald
# geoId/29121,Macon
# geoId/29123,Madison
# geoId/29125,Maries
# geoId/29127,Marion
# geoId/29129,Mercer
# geoId/29131,Miller
# geoId/29133,Mississippi
# geoId/29135,Moniteau
# geoId/29137,Monroe
# geoId/29139,Montgomery
# geoId/29141,Morgan
# geoId/29143,New Madrid
# geoId/29145,Newton
# geoId/29147,Nodaway
# geoId/29149,Oregon
# geoId/29151,Osage
# geoId/29153,Ozark
# geoId/29155,Pemiscot
# geoId/29157,Perry
# geoId/29159,Pettis
# geoId/29161,Phelps
# geoId/29163,Pike
# geoId/29165,Platte
# geoId/29167,Polk
# geoId/29169,Pulaski
# geoId/29171,Putnam
# geoId/29173,Ralls
# geoId/29175,Randolph
# geoId/29177,Ray
# geoId/29179,Reynolds
# geoId/29181,Ripley
# geoId/29185,St. Clair
# geoId/29186,Ste. Genevieve
# geoId/29187,St. Francois
# geoId/29195,Saline
# geoId/29197,Schuyler
# geoId/29199,Scotland
# geoId/29201,Scott
# geoId/29203,Shannon
# geoId/29205,Shelby
# geoId/29207,Stoddard
# geoId/29209,Stone
# geoId/29211,Sullivan
# geoId/29213,Taney
# geoId/29215,Texas
# geoId/29217,Vernon
# geoId/29219,Warren
# geoId/29223,Wayne
# geoId/29227,Worth
# geoId/29229,Wright
# geoId/30001,Beaverhead
# geoId/30003,Big Horn
# geoId/30005,Blaine
# geoId/30007,Broadwater
# geoId/30009,Carbon
# geoId/30011,Carter
# geoId/30013,Cascade
# geoId/30015,Chouteau
# geoId/30017,Custer
# geoId/30019,Daniels
# geoId/30021,Dawson
# geoId/30023,Deer Lodge
# geoId/30025,Fallon
# geoId/30027,Fergus
# geoId/30029,Flathead
# geoId/30033,Garfield
# geoId/30035,Glacier
# geoId/30037,Golden Valley
# geoId/30039,Granite
# geoId/30041,Hill
# geoId/30043,Jefferson
# geoId/30045,Judith Basin
# geoId/30047,Lake
# geoId/30049,Lewis and Clark
# geoId/30051,Liberty
# geoId/30053,Lincoln
# geoId/30055,McCone
# geoId/30057,Madison
# geoId/30059,Meagher
# geoId/30061,Mineral
# geoId/30065,Musselshell
# geoId/30067,Park
# geoId/30069,Petroleum
# geoId/30071,Phillips
# geoId/30073,Pondera
# geoId/30075,Powder River
# geoId/30077,Powell
# geoId/30079,Prairie
# geoId/30081,Ravalli
# geoId/30083,Richland
# geoId/30085,Roosevelt
# geoId/30087,Rosebud
# geoId/30089,Sanders
# geoId/30091,Sheridan
# geoId/30093,Silver Bow
# geoId/30095,Stillwater
# geoId/30097,Sweet Grass
# geoId/30099,Teton
# geoId/30101,Toole
# geoId/30103,Treasure
# geoId/30105,Valley
# geoId/30107,Wheatland
# geoId/30109,Wibaux
# geoId/30111,Yellowstone
# geoId/31001,Adams
# geoId/31003,Antelope
# geoId/31005,Arthur
# geoId/31007,Banner
# geoId/31009,Blaine
# geoId/31011,Boone
# geoId/31013,Box Butte
# geoId/31015,Boyd
# geoId/31017,Brown
# geoId/31019,Buffalo
# geoId/31021,Burt
# geoId/31023,Butler
# geoId/31025,Cass
# geoId/31027,Cedar
# geoId/31029,Chase
# geoId/31031,Cherry
# geoId/31033,Cheyenne
# geoId/31035,Clay
# geoId/31037,Colfax
# geoId/31039,Cuming
# geoId/31041,Custer
# geoId/31043,Dakota
# geoId/31045,Dawes
# geoId/31047,Dawson
# geoId/31049,Deuel
# geoId/31051,Dixon
# geoId/31053,Dodge
# geoId/31057,Dundy
# geoId/31059,Fillmore
# geoId/31061,Franklin
# geoId/31063,Frontier
# geoId/31065,Furnas
# geoId/31067,Gage
# geoId/31069,Garden
# geoId/31071,Garfield
# geoId/31073,Gosper
# geoId/31075,Grant
# geoId/31077,Greeley
# geoId/31079,Hall
# geoId/31081,Hamilton
# geoId/31083,Harlan
# geoId/31085,Hayes
# geoId/31087,Hitchcock
# geoId/31089,Holt
# geoId/31091,Hooker
# geoId/31093,Howard
# geoId/31095,Jefferson
# geoId/31097,Johnson
# geoId/31099,Kearney
# geoId/31101,Keith
# geoId/31103,Keya Paha
# geoId/31105,Kimball
# geoId/31107,Knox
# geoId/31111,Lincoln
# geoId/31113,Logan
# geoId/31115,Loup
# geoId/31117,McPherson
# geoId/31119,Madison
# geoId/31121,Merrick
# geoId/31123,Morrill
# geoId/31125,Nance
# geoId/31127,Nemaha
# geoId/31129,Nuckolls
# geoId/31131,Otoe
# geoId/31133,Pawnee
# geoId/31135,Perkins
# geoId/31137,Phelps
# geoId/31139,Pierce
# geoId/31141,Platte
# geoId/31143,Polk
# geoId/31145,Red Willow
# geoId/31147,Richardson
# geoId/31149,Rock
# geoId/31151,Saline
# geoId/31153,Sarpy
# geoId/31155,Saunders
# geoId/31157,Scotts Bluff
# geoId/31159,Seward
# geoId/31161,Sheridan
# geoId/31163,Sherman
# geoId/31165,Sioux
# geoId/31167,Stanton
# geoId/31169,Thayer
# geoId/31171,Thomas
# geoId/31173,Thurston
# geoId/31175,Valley
# geoId/31177,Washington
# geoId/31179,Wayne
# geoId/31181,Webster
# geoId/31183,Wheeler
# geoId/31185,York
# geoId/32001,Churchill
# geoId/32009,Esmeralda
# geoId/32011,Eureka
# geoId/32013,Humboldt
# geoId/32015,Lander
# geoId/32017,Lincoln
# geoId/32019,Lyon
# geoId/32021,Mineral
# geoId/32023,Nye
# geoId/32027,Pershing
# geoId/32029,Storey
# geoId/32031,Washoe
# geoId/32033,White Pine
# geoId/33001,Belknap
# geoId/33007,Coos
# geoId/33015,Rockingham
# geoId/33017,Strafford
# geoId/34001,Atlantic
# geoId/34003,Bergen
# geoId/34009,Cape May
# geoId/34019,Hunterdon
# geoId/34021,Mercer
# geoId/34029,Ocean
# geoId/34033,Salem
# geoId/34041,Warren
# geoId/35001,Bernalillo
# geoId/35003,Catron
# geoId/35005,Chaves
# geoId/35006,Cibola
# geoId/35007,Colfax
# geoId/35009,Curry
# geoId/35011,De Baca
# geoId/35013,Doña Ana
# geoId/35015,Eddy
# geoId/35017,Grant
# geoId/35019,Guadalupe
# geoId/35021,Harding
# geoId/35023,Hidalgo
# geoId/35025,Lea
# geoId/35027,Lincoln
# geoId/35029,Luna
# geoId/35031,McKinley
# geoId/35033,Mora
# geoId/35035,Otero
# geoId/35037,Quay
# geoId/35039,Rio Arriba
# geoId/35041,Roosevelt
# geoId/35043,Sandoval
# geoId/35045,San Juan
# geoId/35047,San Miguel
# geoId/35051,Sierra
# geoId/35053,Socorro
# geoId/35055,Taos
# geoId/35057,Torrance
# geoId/35059,Union
# geoId/35061,Valencia
# geoId/36003,Allegany
# geoId/36005,Bronx
# geoId/36007,Broome
# geoId/36009,Cattaraugus
# geoId/36011,Cayuga
# geoId/36013,Chautauqua
# geoId/36015,Chemung
# geoId/36021,Columbia
# geoId/36025,Delaware
# geoId/36027,Dutchess
# geoId/36031,Essex
# geoId/36033,Franklin
# geoId/36037,Genesee
# geoId/36039,Greene
# geoId/36041,Hamilton
# geoId/36043,Herkimer
# geoId/36049,Lewis
# geoId/36053,Madison
# geoId/36057,Montgomery
# geoId/36059,Nassau
# geoId/36063,Niagara
# geoId/36069,Ontario
# geoId/36073,Orleans
# geoId/36079,Putnam
# geoId/36083,Rensselaer
# geoId/36089,St. Lawrence
# geoId/36095,Schoharie
# geoId/36097,Schuyler
# geoId/36099,Seneca
# geoId/36101,Steuben
# geoId/36107,Tioga
# geoId/36109,Tompkins
# geoId/36113,Warren
# geoId/36115,Washington
# geoId/36121,Wyoming
# geoId/36123,Yates
# geoId/37001,Alamance
# geoId/37003,Alexander
# geoId/37005,Alleghany
# geoId/37007,Anson
# geoId/37009,Ashe
# geoId/37011,Avery
# geoId/37015,Bertie
# geoId/37017,Bladen
# geoId/37021,Buncombe
# geoId/37025,Cabarrus
# geoId/37029,Camden
# geoId/37033,Caswell
# geoId/37035,Catawba
# geoId/37039,Cherokee
# geoId/37041,Chowan
# geoId/37043,Clay
# geoId/37045,Cleveland
# geoId/37047,Columbus
# geoId/37049,Craven
# geoId/37053,Currituck
# geoId/37055,Dare
# geoId/37059,Davie
# geoId/37061,Duplin
# geoId/37065,Edgecombe
# geoId/37067,Forsyth
# geoId/37069,Franklin
# geoId/37071,Gaston
# geoId/37073,Gates
# geoId/37075,Graham
# geoId/37077,Granville
# geoId/37079,Greene
# geoId/37083,Halifax
# geoId/37085,Harnett
# geoId/37087,Haywood
# geoId/37091,Hertford
# geoId/37093,Hoke
# geoId/37095,Hyde
# geoId/37097,Iredell
# geoId/37099,Jackson
# geoId/37103,Jones
# geoId/37105,Lee
# geoId/37109,Lincoln
# geoId/37111,McDowell
# geoId/37113,Macon
# geoId/37115,Madison
# geoId/37119,Mecklenburg
# geoId/37121,Mitchell
# geoId/37123,Montgomery
# geoId/37127,Nash
# geoId/37129,New Hanover
# geoId/37131,Northampton
# geoId/37133,Onslow
# geoId/37137,Pamlico
# geoId/37139,Pasquotank
# geoId/37141,Pender
# geoId/37143,Perquimans
# geoId/37145,Person
# geoId/37147,Pitt
# geoId/37149,Polk
# geoId/37153,Richmond
# geoId/37155,Robeson
# geoId/37157,Rockingham
# geoId/37159,Rowan
# geoId/37163,Sampson
# geoId/37165,Scotland
# geoId/37167,Stanly
# geoId/37169,Stokes
# geoId/37171,Surry
# geoId/37173,Swain
# geoId/37175,Transylvania
# geoId/37177,Tyrrell
# geoId/37181,Vance
# geoId/37183,Wake
# geoId/37185,Warren
# geoId/37187,Washington
# geoId/37193,Wilkes
# geoId/37197,Yadkin
# geoId/37199,Yancey
# geoId/38001,Adams
# geoId/38003,Barnes
# geoId/38005,Benson
# geoId/38007,Billings
# geoId/38009,Bottineau
# geoId/38011,Bowman
# geoId/38013,Burke
# geoId/38015,Burleigh
# geoId/38017,Cass
# geoId/38019,Cavalier
# geoId/38021,Dickey
# geoId/38023,Divide
# geoId/38025,Dunn
# geoId/38027,Eddy
# geoId/38029,Emmons
# geoId/38031,Foster
# geoId/38033,Golden Valley
# geoId/38037,Grant
# geoId/38039,Griggs
# geoId/38041,Hettinger
# geoId/38043,Kidder
# geoId/38045,LaMoure
# geoId/38047,Logan
# geoId/38049,McHenry
# geoId/38051,McIntosh
# geoId/38053,McKenzie
# geoId/38055,McLean
# geoId/38057,Mercer
# geoId/38061,Mountrail
# geoId/38063,Nelson
# geoId/38065,Oliver
# geoId/38067,Pembina
# geoId/38069,Pierce
# geoId/38071,Ramsey
# geoId/38073,Ransom
# geoId/38075,Renville
# geoId/38077,Richland
# geoId/38079,Rolette
# geoId/38081,Sargent
# geoId/38083,Sheridan
# geoId/38085,Sioux
# geoId/38087,Slope
# geoId/38089,Stark
# geoId/38091,Steele
# geoId/38093,Stutsman
# geoId/38095,Towner
# geoId/38097,Traill
# geoId/38099,Walsh
# geoId/38101,Ward
# geoId/38103,Wells
# geoId/38105,Williams
# geoId/39001,Adams
# geoId/39003,Allen
# geoId/39011,Auglaize
# geoId/39015,Brown
# geoId/39021,Champaign
# geoId/39029,Columbiana
# geoId/39033,Crawford
# geoId/39035,Cuyahoga
# geoId/39037,Darke
# geoId/39043,Erie
# geoId/39047,Fayette
# geoId/39053,Gallia
# geoId/39055,Geauga
# geoId/39057,Greene
# geoId/39059,Guernsey
# geoId/39063,Hancock
# geoId/39065,Hardin
# geoId/39069,Henry
# geoId/39071,Highland
# geoId/39073,Hocking
# geoId/39075,Holmes
# geoId/39079,Jackson
# geoId/39083,Knox
# geoId/39085,Lake
# geoId/39087,Lawrence
# geoId/39089,Licking
# geoId/39091,Logan
# geoId/39095,Lucas
# geoId/39097,Madison
# geoId/39099,Mahoning
# geoId/39105,Meigs
# geoId/39107,Mercer
# geoId/39109,Miami
# geoId/39111,Monroe
# geoId/39115,Morgan
# geoId/39117,Morrow
# geoId/39119,Muskingum
# geoId/39121,Noble
# geoId/39125,Paulding
# geoId/39129,Pickaway
# geoId/39131,Pike
# geoId/39135,Preble
# geoId/39137,Putnam
# geoId/39141,Ross
# geoId/39147,Seneca
# geoId/39151,Stark
# geoId/39157,Tuscarawas
# geoId/39163,Vinton
# geoId/39167,Washington
# geoId/39171,Williams
# geoId/39173,Wood
# geoId/39175,Wyandot
# geoId/40001,Adair
# geoId/40003,Alfalfa
# geoId/40007,Beaver
# geoId/40009,Beckham
# geoId/40011,Blaine
# geoId/40013,Bryan
# geoId/40015,Caddo
# geoId/40017,Canadian
# geoId/40019,Carter
# geoId/40021,Cherokee
# geoId/40025,Cimarron
# geoId/40027,Cleveland
# geoId/40029,Coal
# geoId/40031,Comanche
# geoId/40033,Cotton
# geoId/40035,Craig
# geoId/40037,Creek
# geoId/40039,Custer
# geoId/40041,Delaware
# geoId/40043,Dewey
# geoId/40045,Ellis
# geoId/40049,Garvin
# geoId/40051,Grady
# geoId/40053,Grant
# geoId/40055,Greer
# geoId/40057,Harmon
# geoId/40059,Harper
# geoId/40061,Haskell
# geoId/40063,Hughes
# geoId/40065,Jackson
# geoId/40067,Jefferson
# geoId/40069,Johnston
# geoId/40071,Kay
# geoId/40073,Kingfisher
# geoId/40075,Kiowa
# geoId/40077,Latimer
# geoId/40079,Le Flore
# geoId/40081,Lincoln
# geoId/40083,Logan
# geoId/40085,Love
# geoId/40087,McClain
# geoId/40089,McCurtain
# geoId/40091,McIntosh
# geoId/40093,Major
# geoId/40095,Marshall
# geoId/40097,Mayes
# geoId/40099,Murray
# geoId/40103,Noble
# geoId/40105,Nowata
# geoId/40107,Okfuskee
# geoId/40109,Oklahoma
# geoId/40113,Osage
# geoId/40117,Pawnee
# geoId/40119,Payne
# geoId/40121,Pittsburg
# geoId/40123,Pontotoc
# geoId/40125,Pottawatomie
# geoId/40127,Pushmataha
# geoId/40129,Roger Mills
# geoId/40135,Sequoyah
# geoId/40137,Stephens
# geoId/40139,Texas
# geoId/40141,Tillman
# geoId/40145,Wagoner
# geoId/40147,Washington
# geoId/40149,Washita
# geoId/40151,Woods
# geoId/41005,Clackamas
# geoId/41007,Clatsop
# geoId/41009,Columbia
# geoId/41011,Coos
# geoId/41013,Crook
# geoId/41015,Curry
# geoId/41017,Deschutes
# geoId/41021,Gilliam
# geoId/41023,Grant
# geoId/41025,Harney
# geoId/41027,Hood River
# geoId/41033,Josephine
# geoId/41035,Klamath
# geoId/41037,Lake
# geoId/41039,Lane
# geoId/41041,Lincoln
# geoId/41043,Linn
# geoId/41045,Malheur
# geoId/41049,Morrow
# geoId/41051,Multnomah
# geoId/41053,Polk
# geoId/41055,Sherman
# geoId/41057,Tillamook
# geoId/41059,Umatilla
# geoId/41061,Union
# geoId/41063,Wallowa
# geoId/41065,Wasco
# geoId/41067,Washington
# geoId/41069,Wheeler
# geoId/41071,Yamhill
# geoId/42001,Adams
# geoId/42003,Allegheny
# geoId/42005,Armstrong
# geoId/42007,Beaver
# geoId/42009,Bedford
# geoId/42011,Berks
# geoId/42013,Blair
# geoId/42015,Bradford
# geoId/42017,Bucks
# geoId/42021,Cambria
# geoId/42023,Cameron
# geoId/42025,Carbon
# geoId/42027,Centre
# geoId/42031,Clarion
# geoId/42035,Clinton
# geoId/42039,Crawford
# geoId/42043,Dauphin
# geoId/42045,Delaware
# geoId/42047,Elk
# geoId/42051,Fayette
# geoId/42053,Forest
# geoId/42059,Greene
# geoId/42061,Huntingdon
# geoId/42067,Juniata
# geoId/42073,Lawrence
# geoId/42077,Lehigh
# geoId/42079,Luzerne
# geoId/42081,Lycoming
# geoId/42083,McKean
# geoId/42085,Mercer
# geoId/42087,Mifflin
# geoId/42093,Montour
# geoId/42097,Northumberland
# geoId/42101,Philadelphia
# geoId/42103,Pike
# geoId/42105,Potter
# geoId/42107,Schuylkill
# geoId/42113,Sullivan
# geoId/42115,Susquehanna
# geoId/42117,Tioga
# geoId/42119,Union
# geoId/42121,Venango
# geoId/42123,Warren
# geoId/42127,Wayne
# geoId/42129,Westmoreland
# geoId/42131,Wyoming
# geoId/44009,Washington
# geoId/45005,Allendale
# geoId/45009,Bamberg
# geoId/45011,Barnwell
# geoId/45017,Calhoun
# geoId/45021,Cherokee
# geoId/45023,Chester
# geoId/45025,Chesterfield
# geoId/45027,Clarendon
# geoId/45029,Colleton
# geoId/45031,Darlington
# geoId/45033,Dillon
# geoId/45037,Edgefield
# geoId/45039,Fairfield
# geoId/45043,Georgetown
# geoId/45049,Hampton
# geoId/45051,Horry
# geoId/45055,Kershaw
# geoId/45057,Lancaster
# geoId/45059,Laurens
# geoId/45061,Lee
# geoId/45065,McCormick
# geoId/45067,Marion
# geoId/45069,Marlboro
# geoId/45073,Oconee
# geoId/45077,Pickens
# geoId/45081,Saluda
# geoId/45087,Union
# geoId/46003,Aurora
# geoId/46005,Beadle
# geoId/46007,Bennett
# geoId/46009,Bon Homme
# geoId/46013,Brown
# geoId/46015,Brule
# geoId/46017,Buffalo
# geoId/46019,Butte
# geoId/46021,Campbell
# geoId/46023,Charles Mix
# geoId/46025,Clark
# geoId/46027,Clay
# geoId/46029,Codington
# geoId/46031,Corson
# geoId/46033,Custer
# geoId/46035,Davison
# geoId/46037,Day
# geoId/46039,Deuel
# geoId/46041,Dewey
# geoId/46043,Douglas
# geoId/46045,Edmunds
# geoId/46047,Fall River
# geoId/46049,Faulk
# geoId/46051,Grant
# geoId/46053,Gregory
# geoId/46055,Haakon
# geoId/46057,Hamlin
# geoId/46059,Hand
# geoId/46061,Hanson
# geoId/46063,Harding
# geoId/46065,Hughes
# geoId/46067,Hutchinson
# geoId/46069,Hyde
# geoId/46071,Jackson
# geoId/46073,Jerauld
# geoId/46075,Jones
# geoId/46077,Kingsbury
# geoId/46079,Lake
# geoId/46081,Lawrence
# geoId/46083,Lincoln
# geoId/46085,Lyman
# geoId/46087,McCook
# geoId/46089,McPherson
# geoId/46091,Marshall
# geoId/46093,Meade
# geoId/46095,Mellette
# geoId/46097,Miner
# geoId/46101,Moody
# geoId/46102,Oglala Lakota
# geoId/46103,Pennington
# geoId/46105,Perkins
# geoId/46107,Potter
# geoId/46109,Roberts
# geoId/46111,Sanborn
# geoId/46113,Oglala Lakota
# geoId/46115,Spink
# geoId/46117,Stanley
# geoId/46119,Sully
# geoId/46121,Todd
# geoId/46123,Tripp
# geoId/46125,Turner
# geoId/46127,Union
# geoId/46129,Walworth
# geoId/46137,Ziebach
# geoId/47005,Benton
# geoId/47007,Bledsoe
# geoId/47009,Blount
# geoId/47013,Campbell
# geoId/47015,Cannon
# geoId/47019,Carter
# geoId/47021,Cheatham
# geoId/47023,Chester
# geoId/47027,Clay
# geoId/47029,Cocke
# geoId/47031,Coffee
# geoId/47033,Crockett
# geoId/47039,Decatur
# geoId/47041,DeKalb
# geoId/47047,Fayette
# geoId/47049,Fentress
# geoId/47051,Franklin
# geoId/47053,Gibson
# geoId/47055,Giles
# geoId/47057,Grainger
# geoId/47059,Greene
# geoId/47061,Grundy
# geoId/47063,Hamblen
# geoId/47067,Hancock
# geoId/47069,Hardeman
# geoId/47071,Hardin
# geoId/47073,Hawkins
# geoId/47075,Haywood
# geoId/47077,Henderson
# geoId/47079,Henry
# geoId/47081,Hickman
# geoId/47083,Houston
# geoId/47085,Humphreys
# geoId/47087,Jackson
# geoId/47091,Johnson
# geoId/47093,Knox
# geoId/47095,Lake
# geoId/47097,Lauderdale
# geoId/47099,Lawrence
# geoId/47101,Lewis
# geoId/47103,Lincoln
# geoId/47105,Loudon
# geoId/47107,McMinn
# geoId/47109,McNairy
# geoId/47111,Macon
# geoId/47113,Madison
# geoId/47115,Marion
# geoId/47119,Maury
# geoId/47121,Meigs
# geoId/47127,Moore
# geoId/47129,Morgan
# geoId/47131,Obion
# geoId/47133,Overton
# geoId/47135,Perry
# geoId/47137,Pickett
# geoId/47139,Polk
# geoId/47141,Putnam
# geoId/47143,Rhea
# geoId/47145,Roane
# geoId/47147,Robertson
# geoId/47151,Scott
# geoId/47153,Sequatchie
# geoId/47155,Sevier
# geoId/47159,Smith
# geoId/47161,Stewart
# geoId/47167,Tipton
# geoId/47169,Trousdale
# geoId/47171,Unicoi
# geoId/47173,Union
# geoId/47175,Van Buren
# geoId/47177,Warren
# geoId/47179,Washington
# geoId/47181,Wayne
# geoId/47183,Weakley
# geoId/47185,White
# geoId/47187,Williamson
# geoId/48005,Angelina
# geoId/48007,Aransas
# geoId/48009,Archer
# geoId/48011,Armstrong
# geoId/48013,Atascosa
# geoId/48015,Austin
# geoId/48017,Bailey
# geoId/48019,Bandera
# geoId/48023,Baylor
# geoId/48025,Bee
# geoId/48029,Bexar
# geoId/48031,Blanco
# geoId/48033,Borden
# geoId/48035,Bosque
# geoId/48039,Brazoria
# geoId/48041,Brazos
# geoId/48043,Brewster
# geoId/48045,Briscoe
# geoId/48047,Brooks
# geoId/48049,Brown
# geoId/48051,Burleson
# geoId/48053,Burnet
# geoId/48055,Caldwell
# geoId/48059,Callahan
# geoId/48061,Cameron
# geoId/48063,Camp
# geoId/48065,Carson
# geoId/48067,Cass
# geoId/48069,Castro
# geoId/48071,Chambers
# geoId/48073,Cherokee
# geoId/48075,Childress
# geoId/48077,Clay
# geoId/48079,Cochran
# geoId/48081,Coke
# geoId/48083,Coleman
# geoId/48085,Collin
# geoId/48087,Collingsworth
# geoId/48089,Colorado
# geoId/48091,Comal
# geoId/48093,Comanche
# geoId/48095,Concho
# geoId/48097,Cooke
# geoId/48099,Coryell
# geoId/48101,Cottle
# geoId/48103,Crane
# geoId/48105,Crockett
# geoId/48107,Crosby
# geoId/48109,Culberson
# geoId/48111,Dallam
# geoId/48115,Dawson
# geoId/48117,Deaf Smith
# geoId/48119,Delta
# geoId/48123,DeWitt
# geoId/48125,Dickens
# geoId/48127,Dimmit
# geoId/48129,Donley
# geoId/48131,Duval
# geoId/48133,Eastland
# geoId/48135,Ector
# geoId/48137,Edwards
# geoId/48139,Ellis
# geoId/48143,Erath
# geoId/48145,Falls
# geoId/48147,Fannin
# geoId/48149,Fayette
# geoId/48151,Fisher
# geoId/48153,Floyd
# geoId/48155,Foard
# geoId/48157,Fort Bend
# geoId/48159,Franklin
# geoId/48161,Freestone
# geoId/48163,Frio
# geoId/48165,Gaines
# geoId/48169,Garza
# geoId/48171,Gillespie
# geoId/48173,Glasscock
# geoId/48175,Goliad
# geoId/48179,Gray
# geoId/48181,Grayson
# geoId/48183,Gregg
# geoId/48187,Guadalupe
# geoId/48189,Hale
# geoId/48191,Hall
# geoId/48193,Hamilton
# geoId/48195,Hansford
# geoId/48197,Hardeman
# geoId/48199,Hardin
# geoId/48201,Harris
# geoId/48205,Hartley
# geoId/48207,Haskell
# geoId/48211,Hemphill
# geoId/48217,Hill
# geoId/48219,Hockley
# geoId/48221,Hood
# geoId/48225,Houston
# geoId/48229,Hudspeth
# geoId/48231,Hunt
# geoId/48233,Hutchinson
# geoId/48235,Irion
# geoId/48237,Jack
# geoId/48239,Jackson
# geoId/48243,Jeff Davis
# geoId/48247,Jim Hogg
# geoId/48249,Jim Wells
# geoId/48251,Johnson
# geoId/48253,Jones
# geoId/48255,Karnes
# geoId/48257,Kaufman
# geoId/48259,Kendall
# geoId/48261,Kenedy
# geoId/48263,Kent
# geoId/48265,Kerr
# geoId/48267,Kimble
# geoId/48269,King
# geoId/48271,Kinney
# geoId/48273,Kleberg
# geoId/48275,Knox
# geoId/48277,Lamar
# geoId/48279,Lamb
# geoId/48281,Lampasas
# geoId/48283,La Salle
# geoId/48285,Lavaca
# geoId/48287,Lee
# geoId/48289,Leon
# geoId/48293,Limestone
# geoId/48295,Lipscomb
# geoId/48297,Live Oak
# geoId/48299,Llano
# geoId/48301,Loving
# geoId/48305,Lynn
# geoId/48307,McCulloch
# geoId/48309,McLennan
# geoId/48311,McMullen
# geoId/48313,Madison
# geoId/48315,Marion
# geoId/48317,Martin
# geoId/48319,Mason
# geoId/48321,Matagorda
# geoId/48323,Maverick
# geoId/48327,Menard
# geoId/48331,Milam
# geoId/48333,Mills
# geoId/48335,Mitchell
# geoId/48337,Montague
# geoId/48341,Moore
# geoId/48343,Morris
# geoId/48345,Motley
# geoId/48349,Navarro
# geoId/48351,Newton
# geoId/48353,Nolan
# geoId/48355,Nueces
# geoId/48357,Ochiltree
# geoId/48359,Oldham
# geoId/48363,Palo Pinto
# geoId/48365,Panola
# geoId/48369,Parmer
# geoId/48373,Polk
# geoId/48375,Potter
# geoId/48377,Presidio
# geoId/48379,Rains
# geoId/48381,Randall
# geoId/48383,Reagan
# geoId/48385,Real
# geoId/48387,Red River
# geoId/48389,Reeves
# geoId/48391,Refugio
# geoId/48393,Roberts
# geoId/48395,Robertson
# geoId/48399,Runnels
# geoId/48401,Rusk
# geoId/48403,Sabine
# geoId/48405,San Augustine
# geoId/48407,San Jacinto
# geoId/48409,San Patricio
# geoId/48411,San Saba
# geoId/48413,Schleicher
# geoId/48415,Scurry
# geoId/48417,Shackelford
# geoId/48421,Sherman
# geoId/48423,Smith
# geoId/48425,Somervell
# geoId/48427,Starr
# geoId/48429,Stephens
# geoId/48431,Sterling
# geoId/48433,Stonewall
# geoId/48435,Sutton
# geoId/48437,Swisher
# geoId/48439,Tarrant
# geoId/48443,Terrell
# geoId/48445,Terry
# geoId/48447,Throckmorton
# geoId/48449,Titus
# geoId/48451,Tom Green
# geoId/48453,Travis
# geoId/48455,Trinity
# geoId/48457,Tyler
# geoId/48459,Upshur
# geoId/48461,Upton
# geoId/48465,Val Verde
# geoId/48467,Van Zandt
# geoId/48473,Waller
# geoId/48475,Ward
# geoId/48477,Washington
# geoId/48479,Webb
# geoId/48481,Wharton
# geoId/48483,Wheeler
# geoId/48485,Wichita
# geoId/48487,Wilbarger
# geoId/48489,Willacy
# geoId/48491,Williamson
# geoId/48495,Winkler
# geoId/48497,Wise
# geoId/48499,Wood
# geoId/48501,Yoakum
# geoId/48503,Young
# geoId/48505,Zapata
# geoId/48507,Zavala
# geoId/49001,Beaver
# geoId/49005,Cache
# geoId/49007,Carbon
# geoId/49009,Daggett
# geoId/49013,Duchesne
# geoId/49015,Emery
# geoId/49017,Garfield
# geoId/49019,Grand
# geoId/49021,Iron
# geoId/49023,Juab
# geoId/49025,Kane
# geoId/49027,Millard
# geoId/49029,Morgan
# geoId/49031,Piute
# geoId/49033,Rich
# geoId/49035,Salt Lake
# geoId/49037,San Juan
# geoId/49039,Sanpete
# geoId/49041,Sevier
# geoId/49047,Uintah
# geoId/49049,Utah
# geoId/49051,Wasatch
# geoId/49055,Wayne
# geoId/49057,Weber
# geoId/50007,Chittenden
# geoId/50009,Essex
# geoId/50011,Franklin
# geoId/50013,Grand Isle
# geoId/50015,Lamoille
# geoId/50017,Orange
# geoId/50019,Orleans
# geoId/50023,Washington
# geoId/51001,Accomack
# geoId/51005,Alleghany
# geoId/51007,Amelia
# geoId/51009,Amherst
# geoId/51011,Appomattox
# geoId/51015,Augusta
# geoId/51017,Bath
# geoId/51021,Bland
# geoId/51023,Botetourt
# geoId/51025,Brunswick
# geoId/51027,Buchanan
# geoId/51029,Buckingham
# geoId/51033,Caroline
# geoId/51036,Charles City
# geoId/51037,Charlotte
# geoId/51043,Clarke
# geoId/51045,Craig
# geoId/51049,Cumberland
# geoId/51051,Dickenson
# geoId/51053,Dinwiddie
# geoId/51057,Essex
# geoId/51061,Fauquier
# geoId/51063,Floyd
# geoId/51065,Fluvanna
# geoId/51067,Franklin
# geoId/51071,Giles
# geoId/51075,Goochland
# geoId/51077,Grayson
# geoId/51079,Greene
# geoId/51081,Greensville
# geoId/51083,Halifax
# geoId/51087,Henrico
# geoId/51089,Henry
# geoId/51091,Highland
# geoId/51093,Isle of Wight
# geoId/51095,James City
# geoId/51097,King and Queen
# geoId/51099,King George
# geoId/51101,King William
# geoId/51103,Lancaster
# geoId/51105,Lee
# geoId/51107,Loudoun
# geoId/51109,Louisa
# geoId/51113,Madison
# geoId/51115,Mathews
# geoId/51117,Mecklenburg
# geoId/51119,Middlesex
# geoId/51121,Montgomery
# geoId/51125,Nelson
# geoId/51127,New Kent
# geoId/51131,Northampton
# geoId/51133,Northumberland
# geoId/51135,Nottoway
# geoId/51137,Orange
# geoId/51139,Page
# geoId/51141,Patrick
# geoId/51143,Pittsylvania
# geoId/51145,Powhatan
# geoId/51147,Prince Edward
# geoId/51149,Prince George
# geoId/51153,Prince William
# geoId/51155,Pulaski
# geoId/51157,Rappahannock
# geoId/51159,Richmond
# geoId/51161,Roanoke
# geoId/51163,Rockbridge
# geoId/51165,Rockingham
# geoId/51167,Russell
# geoId/51169,Scott
# geoId/51173,Smyth
# geoId/51175,Southampton
# geoId/51177,Spotsylvania
# geoId/51179,Stafford
# geoId/51181,Surry
# geoId/51183,Sussex
# geoId/51185,Tazewell
# geoId/51187,Warren
# geoId/51191,Washington
# geoId/51193,Westmoreland
# geoId/51195,Wise
# geoId/51197,Wythe
# geoId/53001,Adams
# geoId/53003,Asotin
# geoId/53007,Chelan
# geoId/53009,Clallam
# geoId/53013,Columbia
# geoId/53015,Cowlitz
# geoId/53019,Ferry
# geoId/53023,Garfield
# geoId/53025,Grant
# geoId/53027,Grays Harbor
# geoId/53029,Island
# geoId/53033,King
# geoId/53035,Kitsap
# geoId/53037,Kittitas
# geoId/53039,Klickitat
# geoId/53041,Lewis
# geoId/53043,Lincoln
# geoId/53047,Okanogan
# geoId/53049,Pacific
# geoId/53051,Pend Oreille
# geoId/53053,Pierce
# geoId/53055,San Juan
# geoId/53057,Skagit
# geoId/53059,Skamania
# geoId/53065,Stevens
# geoId/53067,Thurston
# geoId/53069,Wahkiakum
# geoId/53073,Whatcom
# geoId/54001,Barbour
# geoId/54007,Braxton
# geoId/54009,Brooke
# geoId/54011,Cabell
# geoId/54013,Calhoun
# geoId/54015,Clay
# geoId/54017,Doddridge
# geoId/54019,Fayette
# geoId/54021,Gilmer
# geoId/54023,Grant
# geoId/54025,Greenbrier
# geoId/54027,Hampshire
# geoId/54029,Hancock
# geoId/54031,Hardy
# geoId/54035,Jackson
# geoId/54039,Kanawha
# geoId/54041,Lewis
# geoId/54043,Lincoln
# geoId/54045,Logan
# geoId/54047,McDowell
# geoId/54053,Mason
# geoId/54055,Mercer
# geoId/54057,Mineral
# geoId/54059,Mingo
# geoId/54061,Monongalia
# geoId/54063,Monroe
# geoId/54065,Morgan
# geoId/54067,Nicholas
# geoId/54069,Ohio
# geoId/54071,Pendleton
# geoId/54073,Pleasants
# geoId/54075,Pocahontas
# geoId/54077,Preston
# geoId/54079,Putnam
# geoId/54081,Raleigh
# geoId/54083,Randolph
# geoId/54085,Ritchie
# geoId/54087,Roane
# geoId/54089,Summers
# geoId/54091,Taylor
# geoId/54093,Tucker
# geoId/54095,Tyler
# geoId/54097,Upshur
# geoId/54099,Wayne
# geoId/54101,Webster
# geoId/54103,Wetzel
# geoId/54105,Wirt
# geoId/54107,Wood
# geoId/54109,Wyoming
# geoId/55001,Adams
# geoId/55003,Ashland
# geoId/55005,Barron
# geoId/55007,Bayfield
# geoId/55009,Brown
# geoId/55011,Buffalo
# geoId/55013,Burnett
# geoId/55015,Calumet
# geoId/55017,Chippewa
# geoId/55021,Columbia
# geoId/55023,Crawford
# geoId/55025,Dane
# geoId/55027,Dodge
# geoId/55029,Door
# geoId/55033,Dunn
# geoId/55037,Florence
# geoId/55041,Forest
# geoId/55043,Grant
# geoId/55047,Green Lake
# geoId/55049,Iowa
# geoId/55051,Iron
# geoId/55053,Jackson
# geoId/55057,Juneau
# geoId/55061,Kewaunee
# geoId/55065,Lafayette
# geoId/55067,Langlade
# geoId/55069,Lincoln
# geoId/55073,Marathon
# geoId/55077,Marquette
# geoId/55078,Menominee
# geoId/55083,Oconto
# geoId/55087,Outagamie
# geoId/55089,Ozaukee
# geoId/55091,Pepin
# geoId/55093,Pierce
# geoId/55095,Polk
# geoId/55099,Price
# geoId/55103,Richland
# geoId/55105,Rock
# geoId/55107,Rusk
# geoId/55109,St. Croix
# geoId/55111,Sauk
# geoId/55113,Sawyer
# geoId/55115,Shawano
# geoId/55119,Taylor
# geoId/55121,Trempealeau
# geoId/55125,Vilas
# geoId/55127,Walworth
# geoId/55129,Washburn
# geoId/55131,Washington
# geoId/55135,Waupaca
# geoId/55137,Waushara
# geoId/55139,Winnebago
# geoId/55141,Wood
# geoId/56001,Albany
# geoId/56003,Big Horn
# geoId/56007,Carbon
# geoId/56009,Converse
# geoId/56011,Crook
# geoId/56013,Fremont
# geoId/56015,Goshen
# geoId/56017,Hot Springs
# geoId/56019,Johnson
# geoId/56023,Lincoln
# geoId/56025,Natrona
# geoId/56027,Niobrara
# geoId/56029,Park
# geoId/56031,Platte
# geoId/56035,Sublette
# geoId/56039,Teton
# geoId/56041,Uinta
# geoId/56043,Washakie
# geoId/56045,Weston
